# %%
import numpy as np
import geopandas as gpd
from rasterio.plot import reshape_as_raster
import xarray as xr
import rioxarray as rxr
import os
import sys
from sklearn.preprocessing import normalize
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from eofs.xarray import Eof

# %%
sys.path.insert(1, '/global/home/users/drewhart/seasonality/seasonal_asynchrony/etc/')
import phen_helper_fns as phf
# Out:
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):

# %%
# dataset params
dataset = 'NIRv'
#dataset = 'SIF'
masking_mode = 'default'
#masking_mode = 'strict'
mask_filename_ext_dict = {'strict': '_STRICTMASK',
                          'default': ''}
mask_filename_ext = mask_filename_ext_dict[masking_mode]

# %%
# plotting params
subplots_adj_left=0.05
subplots_adj_bottom=0.1
subplots_adj_right=0.95
subplots_adj_top=0.9
subplots_adj_wspace=0.2
subplots_adj_hspace=0.4

# %%
# NOTE on memory requirements
    #        I estimate that the global 365 x 2400 x 6900 raster will take up
    #       about 46.1 GB memory;
    #       (NOTE: I could also cast of dtype float32 and cut down to ~23 GB,
    #              for 'safety' sake)
    #       if I ran this on savio bigmem that would only be ~1/9th total RAM,
    #       so it should be doable to create a giant global 365 x 2400 x 6900
    #       numpy array and then fill it with all fitted time series and write
    #       to disk, though that's only ~1/2 RAM on savio3, so first just try
    #       there!
    #       then I could separately read in as a dask array and run EOF
    #       analysis on that, I believe.
    #       though I wonder if I could just run the EOF analysis within that
    #       same job. Not sure how much memory requirement expands as factor
    #       of size of base spatiotemporal dataset, and not easily finding that
    #       informiation on line...


# TODO:

    # could use clustering afterward, with scree plot, to determine k
    # distinct 'classes' of global phenological seasonality 'types'

# %%
###################
# BEHAVIORAL PARAMS
###################

# min and max x and y values, to optionally subset analysis to a region
region_name = 'global'
min_x = None
max_x = None
min_y = None
max_y = None


# use hvplot, etc for interactive plotting?
interactive = False

# save figures and datasets?
save_res = True

# data dir on laptop
if os.getcwd().split('/')[1] == 'home':
    data_dir = '/home/deth/Desktop/CAL/research/projects/seasonality/results/maps'
# data dir on savio
else:
    data_dir = os.path.join('/global/scratch/users/drewhart/seasonality/GEE_outputs',
                            dataset + mask_filename_ext)

# set the seed
set_seed = True
if set_seed:
    seed = 1
    np.random.seed(seed)

# normalize each ts to itself?
# NOTE: it makes sense to do this, since I'm only interested in timing,
#       and otherwise (especially based on Alex Turner's results in CA) I
#       expect the first EOF will largely reflect global (i.e.,
#       cross-study-area) variation in magnitude of fitted values;
#       nonetheless, setting a flag for this so that I can check that
#       expectation and check sensitivity to this decision
normalize_ts = True

# latitude weights to use?
#lat_weights = None
#lat_weights = 'cos'
lat_weights = 'sqrt_cos'

# center the data being input to EOF?
center_eof = True

# number of top EOFs to use?
neofs = 4

# pctiles and counts of example time series to plot?
ts_top_pctile = 95
ts_bot_pctile = 95
n_ts_to_plot = 1000

# %%
########################################
# READ IN COEFFS, GET ARRAY OF FITTED TS
########################################

# read global NIRv coeffs
coeffs = rxr.open_rasterio(os.path.join(data_dir, '%s%s_coeffs.tif' % (dataset, mask_filename_ext)))

# subset global raster to study area (if all Nones then not subsetted!)
# NOTE: max_y and min_y flipped because y res negative in CRS transform
coeffs = coeffs.sel(x=slice(min_x, max_x), y=slice(max_y, min_y))

# get coords arrays
X, Y = np.meshgrid(coeffs.x, coeffs.y)

# %%
# create empty time-series array for EOF analysis
ts_arr = np.ones((365, coeffs.shape[1], coeffs.shape[2]), dtype=np.float32) * np.nan

# make the harmonic regression's design matrix
dm = phf.make_design_matrix()

# get i and j values for non-null pixels that need time series calculated
I, J = np.where(pd.notnull(coeffs[0,:,:]))

# get the time series for non-null pixel
# NOTE: coeffs.shape[0] == 5, one band for each regression coeff
for n in range(len(I)):
    i = I[n]
    j = J[n]
    coeffs_vec = coeffs[:, i, j].values
    ts = np.sum(coeffs_vec * dm, axis=1)
    # normalize time series [0,1], if desired
    # NOTE: if not, pretty certain that first EOF will largely capture
    #       global (i.e., across full subsetted extent) variation
    #       in fitted magnitude
    if normalize_ts and not np.any(np.isnan(ts)):
        ts = normalize([ts]).flatten()
    assert ts.shape == (365,)
    ts_arr[:, i, j] = ts
    if n%10000 == 0:
        print(f"\n\n\t{np.round(100*((n+1)/len(I)), 1)}% complete'")

# once complete, save this to a simple numpy array file
# (for now, anyhow; might be worth saving as a big geospatial file
#  eventually?)
if save_res:
    print('\n\n\tNOW SAVING TIME SERIES CUBE...\n\n(this will take some time...)')
    np.savetxt(os.path.join(data_dir, 'fitted_ts_array_%s%s.txt' % (dataset, mask_filename_ext)),
            ts_arr.reshape(ts_arr.shape[0], -1))
# Out:
# 	0.0% complete'
#
#
# 	0.1% complete'
#
#
# 	0.1% complete'
#
#
# 	0.2% complete'
#
#
# 	0.3% complete'
#
#
# 	0.4% complete'
#
#
# 	0.4% complete'
#
#
# 	0.5% complete'
#
#
# 	0.6% complete'
#
#
# 	0.7% complete'
#
#
# 	0.7% complete'
#
#
# 	0.8% complete'
#
#
# 	0.9% complete'
#
#
# 	1.0% complete'
#
#
# 	1.0% complete'
#
#
# 	1.1% complete'
#
#
# 	1.2% complete'
#
#
# 	1.3% complete'
#
#
# 	1.3% complete'
#
#
# 	1.4% complete'
#
#
# 	1.5% complete'
#
#
# 	1.6% complete'
#
#
# 	1.6% complete'
#
#
# 	1.7% complete'
#
#
# 	1.8% complete'
#
#
# 	1.9% complete'
#
#
# 	1.9% complete'
#
#
# 	2.0% complete'
#
#
# 	2.1% complete'
#
#
# 	2.2% complete'
#
#
# 	2.2% complete'
#
#
# 	2.3% complete'
#
#
# 	2.4% complete'
#
#
# 	2.5% complete'
#
#
# 	2.5% complete'
#
#
# 	2.6% complete'
#
#
# 	2.7% complete'
#
#
# 	2.8% complete'
#
#
# 	2.8% complete'
#
#
# 	2.9% complete'
#
#
# 	3.0% complete'
#
#
# 	3.1% complete'
#
#
# 	3.1% complete'
#
#
# 	3.2% complete'
#
#
# 	3.3% complete'
#
#
# 	3.4% complete'
#
#
# 	3.4% complete'
#
#
# 	3.5% complete'
#
#
# 	3.6% complete'
#
#
# 	3.7% complete'
#
#
# 	3.7% complete'
#
#
# 	3.8% complete'
#
#
# 	3.9% complete'
#
#
# 	4.0% complete'
#
#
# 	4.0% complete'
#
#
# 	4.1% complete'
#
#
# 	4.2% complete'
#
#
# 	4.3% complete'
#
#
# 	4.3% complete'
#
#
# 	4.4% complete'
#
#
# 	4.5% complete'
#
#
# 	4.6% complete'
#
#
# 	4.6% complete'
#
#
# 	4.7% complete'
#
#
# 	4.8% complete'
#
#
# 	4.8% complete'
#
#
# 	4.9% complete'
#
#
# 	5.0% complete'
#
#
# 	5.1% complete'
#
#
# 	5.1% complete'
#
#
# 	5.2% complete'
#
#
# 	5.3% complete'
#
#
# 	5.4% complete'
#
#
# 	5.4% complete'
#
#
# 	5.5% complete'
#
#
# 	5.6% complete'
#
#
# 	5.7% complete'
#
#
# 	5.7% complete'
#
#
# 	5.8% complete'
#
#
# 	5.9% complete'
#
#
# 	6.0% complete'
#
#
# 	6.0% complete'
#
#
# 	6.1% complete'
#
#
# 	6.2% complete'
#
#
# 	6.3% complete'
#
#
# 	6.3% complete'
#
#
# 	6.4% complete'
#
#
# 	6.5% complete'
#
#
# 	6.6% complete'
#
#
# 	6.6% complete'
#
#
# 	6.7% complete'
#
#
# 	6.8% complete'
#
#
# 	6.9% complete'
#
#
# 	6.9% complete'
#
#
# 	7.0% complete'
#
#
# 	7.1% complete'
#
#
# 	7.2% complete'
#
#
# 	7.2% complete'
#
#
# 	7.3% complete'
#
#
# 	7.4% complete'
#
#
# 	7.5% complete'
#
#
# 	7.5% complete'
#
#
# 	7.6% complete'
#
#
# 	7.7% complete'
#
#
# 	7.8% complete'
#
#
# 	7.8% complete'
#
#
# 	7.9% complete'
#
#
# 	8.0% complete'
#
#
# 	8.1% complete'
#
#
# 	8.1% complete'
#
#
# 	8.2% complete'
#
#
# 	8.3% complete'
#
#
# 	8.4% complete'
#
#
# 	8.4% complete'
#
#
# 	8.5% complete'
#
#
# 	8.6% complete'
#
#
# 	8.7% complete'
#
#
# 	8.7% complete'
#
#
# 	8.8% complete'
#
#
# 	8.9% complete'
#
#
# 	9.0% complete'
#
#
# 	9.0% complete'
#
#
# 	9.1% complete'
#
#
# 	9.2% complete'
#
#
# 	9.3% complete'
#
#
# 	9.3% complete'
#
#
# 	9.4% complete'
#
#
# 	9.5% complete'
#
#
# 	9.5% complete'
#
#
# 	9.6% complete'
#
#
# 	9.7% complete'
#
#
# 	9.8% complete'
#
#
# 	9.8% complete'
#
#
# 	9.9% complete'
#
#
# 	10.0% complete'
#
#
# 	10.1% complete'
#
#
# 	10.1% complete'
#
#
# 	10.2% complete'
#
#
# 	10.3% complete'
#
#
# 	10.4% complete'
#
#
# 	10.4% complete'
#
#
# 	10.5% complete'
#
#
# 	10.6% complete'
#
#
# 	10.7% complete'
#
#
# 	10.7% complete'
#
#
# 	10.8% complete'
#
#
# 	10.9% complete'
#
#
# 	11.0% complete'
#
#
# 	11.0% complete'
#
#
# 	11.1% complete'
#
#
# 	11.2% complete'
#
#
# 	11.3% complete'
#
#
# 	11.3% complete'
#
#
# 	11.4% complete'
#
#
# 	11.5% complete'
#
#
# 	11.6% complete'
#
#
# 	11.6% complete'
#
#
# 	11.7% complete'
#
#
# 	11.8% complete'
#
#
# 	11.9% complete'
#
#
# 	11.9% complete'
#
#
# 	12.0% complete'
#
#
# 	12.1% complete'
#
#
# 	12.2% complete'
#
#
# 	12.2% complete'
#
#
# 	12.3% complete'
#
#
# 	12.4% complete'
#
#
# 	12.5% complete'
#
#
# 	12.5% complete'
#
#
# 	12.6% complete'
#
#
# 	12.7% complete'
#
#
# 	12.8% complete'
#
#
# 	12.8% complete'
#
#
# 	12.9% complete'
#
#
# 	13.0% complete'
#
#
# 	13.1% complete'
#
#
# 	13.1% complete'
#
#
# 	13.2% complete'
#
#
# 	13.3% complete'
#
#
# 	13.4% complete'
#
#
# 	13.4% complete'
#
#
# 	13.5% complete'
#
#
# 	13.6% complete'
#
#
# 	13.7% complete'
#
#
# 	13.7% complete'
#
#
# 	13.8% complete'
#
#
# 	13.9% complete'
#
#
# 	13.9% complete'
#
#
# 	14.0% complete'
#
#
# 	14.1% complete'
#
#
# 	14.2% complete'
#
#
# 	14.2% complete'
#
#
# 	14.3% complete'
#
#
# 	14.4% complete'
#
#
# 	14.5% complete'
#
#
# 	14.5% complete'
#
#
# 	14.6% complete'
#
#
# 	14.7% complete'
#
#
# 	14.8% complete'
#
#
# 	14.8% complete'
#
#
# 	14.9% complete'
#
#
# 	15.0% complete'
#
#
# 	15.1% complete'
#
#
# 	15.1% complete'
#
#
# 	15.2% complete'
#
#
# 	15.3% complete'
#
#
# 	15.4% complete'
#
#
# 	15.4% complete'
#
#
# 	15.5% complete'
#
#
# 	15.6% complete'
#
#
# 	15.7% complete'
#
#
# 	15.7% complete'
#
#
# 	15.8% complete'
#
#
# 	15.9% complete'
#
#
# 	16.0% complete'
#
#
# 	16.0% complete'
#
#
# 	16.1% complete'
#
#
# 	16.2% complete'
#
#
# 	16.3% complete'
#
#
# 	16.3% complete'
#
#
# 	16.4% complete'
#
#
# 	16.5% complete'
#
#
# 	16.6% complete'
#
#
# 	16.6% complete'
#
#
# 	16.7% complete'
#
#
# 	16.8% complete'
#
#
# 	16.9% complete'
#
#
# 	16.9% complete'
#
#
# 	17.0% complete'
#
#
# 	17.1% complete'
#
#
# 	17.2% complete'
#
#
# 	17.2% complete'
#
#
# 	17.3% complete'
#
#
# 	17.4% complete'
#
#
# 	17.5% complete'
#
#
# 	17.5% complete'
#
#
# 	17.6% complete'
#
#
# 	17.7% complete'
#
#
# 	17.8% complete'
#
#
# 	17.8% complete'
#
#
# 	17.9% complete'
#
#
# 	18.0% complete'
#
#
# 	18.1% complete'
#
#
# 	18.1% complete'
#
#
# 	18.2% complete'
#
#
# 	18.3% complete'
#
#
# 	18.4% complete'
#
#
# 	18.4% complete'
#
#
# 	18.5% complete'
#
#
# 	18.6% complete'
#
#
# 	18.6% complete'
#
#
# 	18.7% complete'
#
#
# 	18.8% complete'
#
#
# 	18.9% complete'
#
#
# 	18.9% complete'
#
#
# 	19.0% complete'
#
#
# 	19.1% complete'
#
#
# 	19.2% complete'
#
#
# 	19.2% complete'
#
#
# 	19.3% complete'
#
#
# 	19.4% complete'
#
#
# 	19.5% complete'
#
#
# 	19.5% complete'
#
#
# 	19.6% complete'
#
#
# 	19.7% complete'
#
#
# 	19.8% complete'
#
#
# 	19.8% complete'
#
#
# 	19.9% complete'
#
#
# 	20.0% complete'
#
#
# 	20.1% complete'
#
#
# 	20.1% complete'
#
#
# 	20.2% complete'
#
#
# 	20.3% complete'
#
#
# 	20.4% complete'
#
#
# 	20.4% complete'
#
#
# 	20.5% complete'
#
#
# 	20.6% complete'
#
#
# 	20.7% complete'
#
#
# 	20.7% complete'
#
#
# 	20.8% complete'
#
#
# 	20.9% complete'
#
#
# 	21.0% complete'
#
#
# 	21.0% complete'
#
#
# 	21.1% complete'
#
#
# 	21.2% complete'
#
#
# 	21.3% complete'
#
#
# 	21.3% complete'
#
#
# 	21.4% complete'
#
#
# 	21.5% complete'
#
#
# 	21.6% complete'
#
#
# 	21.6% complete'
#
#
# 	21.7% complete'
#
#
# 	21.8% complete'
#
#
# 	21.9% complete'
#
#
# 	21.9% complete'
#
#
# 	22.0% complete'
#
#
# 	22.1% complete'
#
#
# 	22.2% complete'
#
#
# 	22.2% complete'
#
#
# 	22.3% complete'
#
#
# 	22.4% complete'
#
#
# 	22.5% complete'
#
#
# 	22.5% complete'
#
#
# 	22.6% complete'
#
#
# 	22.7% complete'
#
#
# 	22.8% complete'
#
#
# 	22.8% complete'
#
#
# 	22.9% complete'
#
#
# 	23.0% complete'
#
#
# 	23.1% complete'
#
#
# 	23.1% complete'
#
#
# 	23.2% complete'
#
#
# 	23.3% complete'
#
#
# 	23.3% complete'
#
#
# 	23.4% complete'
#
#
# 	23.5% complete'
#
#
# 	23.6% complete'
#
#
# 	23.6% complete'
#
#
# 	23.7% complete'
#
#
# 	23.8% complete'
#
#
# 	23.9% complete'
#
#
# 	23.9% complete'
#
#
# 	24.0% complete'
#
#
# 	24.1% complete'
#
#
# 	24.2% complete'
#
#
# 	24.2% complete'
#
#
# 	24.3% complete'
#
#
# 	24.4% complete'
#
#
# 	24.5% complete'
#
#
# 	24.5% complete'
#
#
# 	24.6% complete'
#
#
# 	24.7% complete'
#
#
# 	24.8% complete'
#
#
# 	24.8% complete'
#
#
# 	24.9% complete'
#
#
# 	25.0% complete'
#
#
# 	25.1% complete'
#
#
# 	25.1% complete'
#
#
# 	25.2% complete'
#
#
# 	25.3% complete'
#
#
# 	25.4% complete'
#
#
# 	25.4% complete'
#
#
# 	25.5% complete'
#
#
# 	25.6% complete'
#
#
# 	25.7% complete'
#
#
# 	25.7% complete'
#
#
# 	25.8% complete'
#
#
# 	25.9% complete'
#
#
# 	26.0% complete'
#
#
# 	26.0% complete'
#
#
# 	26.1% complete'
#
#
# 	26.2% complete'
#
#
# 	26.3% complete'
#
#
# 	26.3% complete'
#
#
# 	26.4% complete'
#
#
# 	26.5% complete'
#
#
# 	26.6% complete'
#
#
# 	26.6% complete'
#
#
# 	26.7% complete'
#
#
# 	26.8% complete'
#
#
# 	26.9% complete'
#
#
# 	26.9% complete'
#
#
# 	27.0% complete'
#
#
# 	27.1% complete'
#
#
# 	27.2% complete'
#
#
# 	27.2% complete'
#
#
# 	27.3% complete'
#
#
# 	27.4% complete'
#
#
# 	27.5% complete'
#
#
# 	27.5% complete'
#
#
# 	27.6% complete'
#
#
# 	27.7% complete'
#
#
# 	27.8% complete'
#
#
# 	27.8% complete'
#
#
# 	27.9% complete'
#
#
# 	28.0% complete'
#
#
# 	28.0% complete'
#
#
# 	28.1% complete'
#
#
# 	28.2% complete'
#
#
# 	28.3% complete'
#
#
# 	28.3% complete'
#
#
# 	28.4% complete'
#
#
# 	28.5% complete'
#
#
# 	28.6% complete'
#
#
# 	28.6% complete'
#
#
# 	28.7% complete'
#
#
# 	28.8% complete'
#
#
# 	28.9% complete'
#
#
# 	28.9% complete'
#
#
# 	29.0% complete'
#
#
# 	29.1% complete'
#
#
# 	29.2% complete'
#
#
# 	29.2% complete'
#
#
# 	29.3% complete'
#
#
# 	29.4% complete'
#
#
# 	29.5% complete'
#
#
# 	29.5% complete'
#
#
# 	29.6% complete'
#
#
# 	29.7% complete'
#
#
# 	29.8% complete'
#
#
# 	29.8% complete'
#
#
# 	29.9% complete'
#
#
# 	30.0% complete'
#
#
# 	30.1% complete'
#
#
# 	30.1% complete'
#
#
# 	30.2% complete'
#
#
# 	30.3% complete'
#
#
# 	30.4% complete'
#
#
# 	30.4% complete'
#
#
# 	30.5% complete'
#
#
# 	30.6% complete'
#
#
# 	30.7% complete'
#
#
# 	30.7% complete'
#
#
# 	30.8% complete'
#
#
# 	30.9% complete'
#
#
# 	31.0% complete'
#
#
# 	31.0% complete'
#
#
# 	31.1% complete'
#
#
# 	31.2% complete'
#
#
# 	31.3% complete'
#
#
# 	31.3% complete'
#
#
# 	31.4% complete'
#
#
# 	31.5% complete'
#
#
# 	31.6% complete'
#
#
# 	31.6% complete'
#
#
# 	31.7% complete'
#
#
# 	31.8% complete'
#
#
# 	31.9% complete'
#
#
# 	31.9% complete'
#
#
# 	32.0% complete'
#
#
# 	32.1% complete'
#
#
# 	32.2% complete'
#
#
# 	32.2% complete'
#
#
# 	32.3% complete'
#
#
# 	32.4% complete'
#
#
# 	32.4% complete'
#
#
# 	32.5% complete'
#
#
# 	32.6% complete'
#
#
# 	32.7% complete'
# 	32.7% complete'
#
#
# 	32.8% complete'
#
#
# 	32.9% complete'
#
#
# 	33.0% complete'
#
#
# 	33.0% complete'
#
#
# 	33.1% complete'
#
#
# 	33.2% complete'
#
#
# 	33.3% complete'
#
#
# 	33.3% complete'
#
#
# 	33.4% complete'
#
#
# 	33.5% complete'
#
#
# 	33.6% complete'
#
#
# 	33.6% complete'
#
#
# 	33.7% complete'
#
#
# 	33.8% complete'
#
#
# 	33.9% complete'
#
#
# 	33.9% complete'
#
#
# 	34.0% complete'
#
#
# 	34.1% complete'
#
#
# 	34.2% complete'
#
#
# 	34.2% complete'
#
#
# 	34.3% complete'
#
#
# 	34.4% complete'
#
#
# 	34.5% complete'
#
#
# 	34.5% complete'
#
#
# 	34.6% complete'
#
#
# 	34.7% complete'
#
#
# 	34.8% complete'
#
#
# 	34.8% complete'
#
#
# 	34.9% complete'
#
#
# 	35.0% complete'
#
#
# 	35.1% complete'
#
#
# 	35.1% complete'
#
#
# 	35.2% complete'
#
#
# 	35.3% complete'
#
#
# 	35.4% complete'
#
#
# 	35.4% complete'
#
#
# 	35.5% complete'
#
#
# 	35.6% complete'
#
#
# 	35.7% complete'
#
#
# 	35.7% complete'
#
#
# 	35.8% complete'
#
#
# 	35.9% complete'
#
#
# 	36.0% complete'
#
#
# 	36.0% complete'
#
#
# 	36.1% complete'
#
#
# 	36.2% complete'
#
#
# 	36.3% complete'
#
#
# 	36.3% complete'
#
#
# 	36.4% complete'
#
#
# 	36.5% complete'
#
#
# 	36.6% complete'
#
#
# 	36.6% complete'
#
#
# 	36.7% complete'
#
#
# 	36.8% complete'
#
#
# 	36.9% complete'
#
#
# 	36.9% complete'
#
#
# 	37.0% complete'
#
#
# 	37.1% complete'
#
#
# 	37.1% complete'
#
#
# 	37.2% complete'
#
#
# 	37.3% complete'
#
#
# 	37.4% complete'
#
#
# 	37.4% complete'
#
#
# 	37.5% complete'
#
#
# 	37.6% complete'
#
#
# 	37.7% complete'
#
#
# 	37.7% complete'
#
#
# 	37.8% complete'
#
#
# 	37.9% complete'
#
#
# 	38.0% complete'
#
#
# 	38.0% complete'
#
#
# 	38.1% complete'
#
#
# 	38.2% complete'
#
#
# 	38.3% complete'
#
#
# 	38.3% complete'
#
#
# 	38.4% complete'
#
#
# 	38.5% complete'
#
#
# 	38.6% complete'
#
#
# 	38.6% complete'
#
#
# 	38.7% complete'
#
#
# 	38.8% complete'
#
#
# 	38.9% complete'
#
#
# 	38.9% complete'
#
#
# 	39.0% complete'
#
#
# 	39.1% complete'
#
#
# 	39.2% complete'
#
#
# 	39.2% complete'
#
#
# 	39.3% complete'
#
#
# 	39.4% complete'
#
#
# 	39.5% complete'
#
#
# 	39.5% complete'
#
#
# 	39.6% complete'
#
#
# 	39.7% complete'
#
#
# 	39.8% complete'
#
#
# 	39.8% complete'
#
#
# 	39.9% complete'
#
#
# 	40.0% complete'
#
#
# 	40.1% complete'
#
#
# 	40.1% complete'
#
#
# 	40.2% complete'
#
#
# 	40.3% complete'
#
#
# 	40.4% complete'
#
#
# 	40.4% complete'
#
#
# 	40.5% complete'
#
#
# 	40.6% complete'
#
#
# 	40.7% complete'
#
#
# 	40.7% complete'
#
#
# 	40.8% complete'
#
#
# 	40.9% complete'
#
#
# 	41.0% complete'
#
#
# 	41.0% complete'
#
#
# 	41.1% complete'
#
#
# 	41.2% complete'
#
#
# 	41.3% complete'
#
#
# 	41.3% complete'
#
#
# 	41.4% complete'
#
#
# 	41.5% complete'
#
#
# 	41.6% complete'
#
#
# 	41.6% complete'
#
#
# 	41.7% complete'
#
#
# 	41.8% complete'
#
#
# 	41.8% complete'
#
#
# 	41.9% complete'
#
#
# 	42.0% complete'
#
#
# 	42.1% complete'
#
#
# 	42.1% complete'
#
#
# 	42.2% complete'
#
#
# 	42.3% complete'
#
#
# 	42.4% complete'
#
#
# 	42.4% complete'
#
#
# 	42.5% complete'
#
#
# 	42.6% complete'
#
#
# 	42.7% complete'
#
#
# 	42.7% complete'
#
#
# 	42.8% complete'
#
#
# 	42.9% complete'
#
#
# 	43.0% complete'
#
#
# 	43.0% complete'
#
#
# 	43.1% complete'
#
#
# 	43.2% complete'
#
#
# 	43.3% complete'
#
#
# 	43.3% complete'
#
#
# 	43.4% complete'
#
#
# 	43.5% complete'
#
#
# 	43.6% complete'
#
#
# 	43.6% complete'
#
#
# 	43.7% complete'
#
#
# 	43.8% complete'
#
#
# 	43.9% complete'
#
#
# 	43.9% complete'
#
#
# 	44.0% complete'
#
#
# 	44.1% complete'
#
#
# 	44.2% complete'
#
#
# 	44.2% complete'
#
#
# 	44.3% complete'
#
#
# 	44.4% complete'
#
#
# 	44.5% complete'
#
#
# 	44.5% complete'
#
#
# 	44.6% complete'
#
#
# 	44.7% complete'
#
#
# 	44.8% complete'
#
#
# 	44.8% complete'
#
#
# 	44.9% complete'
#
#
# 	45.0% complete'
#
#
# 	45.1% complete'
#
#
# 	45.1% complete'
#
#
# 	45.2% complete'
#
#
# 	45.3% complete'
#
#
# 	45.4% complete'
#
#
# 	45.4% complete'
#
#
# 	45.5% complete'
#
#
# 	45.6% complete'
#
#
# 	45.7% complete'
#
#
# 	45.7% complete'
#
#
# 	45.8% complete'
#
#
# 	45.9% complete'
#
#
# 	46.0% complete'
#
#
# 	46.0% complete'
#
#
# 	46.1% complete'
#
#
# 	46.2% complete'
#
#
# 	46.3% complete'
#
#
# 	46.3% complete'
#
#
# 	46.4% complete'
#
#
# 	46.5% complete'
#
#
# 	46.5% complete'
#
#
# 	46.6% complete'
#
#
# 	46.7% complete'
#
#
# 	46.8% complete'
#
#
# 	46.8% complete'
#
#
# 	46.9% complete'
#
#
# 	47.0% complete'
#
#
# 	47.1% complete'
#
#
# 	47.1% complete'
#
#
# 	47.2% complete'
#
#
# 	47.3% complete'
#
#
# 	47.4% complete'
#
#
# 	47.4% complete'
#
#
# 	47.5% complete'
#
#
# 	47.6% complete'
#
#
# 	47.7% complete'
#
#
# 	47.7% complete'
#
#
# 	47.8% complete'
#
#
# 	47.9% complete'
#
#
# 	48.0% complete'
#
#
# 	48.0% complete'
#
#
# 	48.1% complete'
#
#
# 	48.2% complete'
#
#
# 	48.3% complete'
#
#
# 	48.3% complete'
#
#
# 	48.4% complete'
#
#
# 	48.5% complete'
#
#
# 	48.6% complete'
#
#
# 	48.6% complete'
#
#
# 	48.7% complete'
#
#
# 	48.8% complete'
#
#
# 	48.9% complete'
#
#
# 	48.9% complete'
#
#
# 	49.0% complete'
#
#
# 	49.1% complete'
#
#
# 	49.2% complete'
#
#
# 	49.2% complete'
#
#
# 	49.3% complete'
#
#
# 	49.4% complete'
#
#
# 	49.5% complete'
#
#
# 	49.5% complete'
#
#
# 	49.6% complete'
#
#
# 	49.7% complete'
#
#
# 	49.8% complete'
#
#
# 	49.8% complete'
#
#
# 	49.9% complete'
#
#
# 	50.0% complete'
#
#
# 	50.1% complete'
#
#
# 	50.1% complete'
#
#
# 	50.2% complete'
#
#
# 	50.3% complete'
#
#
# 	50.4% complete'
#
#
# 	50.4% complete'
#
#
# 	50.5% complete'
#
#
# 	50.6% complete'
#
#
# 	50.7% complete'
#
#
# 	50.7% complete'
#
#
# 	50.8% complete'
#
#
# 	50.9% complete'
#
#
# 	51.0% complete'
#
#
# 	51.0% complete'
#
#
# 	51.1% complete'
#
#
# 	51.2% complete'
#
#
# 	51.2% complete'
#
#
# 	51.3% complete'
#
#
# 	51.4% complete'
#
#
# 	51.5% complete'
#
#
# 	51.5% complete'
#
#
# 	51.6% complete'
#
#
# 	51.7% complete'
#
#
# 	51.8% complete'
#
#
# 	51.8% complete'
#
#
# 	51.9% complete'
#
#
# 	52.0% complete'
#
#
# 	52.1% complete'
#
#
# 	52.1% complete'
#
#
# 	52.2% complete'
#
#
# 	52.3% complete'
#
#
# 	52.4% complete'
#
#
# 	52.4% complete'
#
#
# 	52.5% complete'
#
#
# 	52.6% complete'
#
#
# 	52.7% complete'
#
#
# 	52.7% complete'
#
#
# 	52.8% complete'
#
#
# 	52.9% complete'
#
#
# 	53.0% complete'
#
#
# 	53.0% complete'
#
#
# 	53.1% complete'
#
#
# 	53.2% complete'
#
#
# 	53.3% complete'
#
#
# 	53.3% complete'
#
#
# 	53.4% complete'
#
#
# 	53.5% complete'
#
#
# 	53.6% complete'
#
#
# 	53.6% complete'
#
#
# 	53.7% complete'
#
#
# 	53.8% complete'
#
#
# 	53.9% complete'
#
#
# 	53.9% complete'
#
#
# 	54.0% complete'
#
#
# 	54.1% complete'
#
#
# 	54.2% complete'
#
#
# 	54.2% complete'
#
#
# 	54.3% complete'
#
#
# 	54.4% complete'
#
#
# 	54.5% complete'
#
#
# 	54.5% complete'
#
#
# 	54.6% complete'
#
#
# 	54.7% complete'
#
#
# 	54.8% complete'
#
#
# 	54.8% complete'
#
#
# 	54.9% complete'
#
#
# 	55.0% complete'
#
#
# 	55.1% complete'
#
#
# 	55.1% complete'
#
#
# 	55.2% complete'
#
#
# 	55.3% complete'
#
#
# 	55.4% complete'
#
#
# 	55.4% complete'
#
#
# 	55.5% complete'
#
#
# 	55.6% complete'
#
#
# 	55.6% complete'
#
#
# 	55.7% complete'
#
#
# 	55.8% complete'
#
#
# 	55.9% complete'
#
#
# 	55.9% complete'
#
#
# 	56.0% complete'
#
#
# 	56.1% complete'
#
#
# 	56.2% complete'
#
#
# 	56.2% complete'
#
#
# 	56.3% complete'
#
#
# 	56.4% complete'
#
#
# 	56.5% complete'
#
#
# 	56.5% complete'
#
#
# 	56.6% complete'
#
#
# 	56.7% complete'
#
#
# 	56.8% complete'
#
#
# 	56.8% complete'
#
#
# 	56.9% complete'
#
#
# 	57.0% complete'
#
#
# 	57.1% complete'
#
#
# 	57.1% complete'
#
#
# 	57.2% complete'
#
#
# 	57.3% complete'
#
#
# 	57.4% complete'
#
#
# 	57.4% complete'
#
#
# 	57.5% complete'
#
#
# 	57.6% complete'
#
#
# 	57.7% complete'
#
#
# 	57.7% complete'
#
#
# 	57.8% complete'
#
#
# 	57.9% complete'
#
#
# 	58.0% complete'
#
#
# 	58.0% complete'
#
#
# 	58.1% complete'
#
#
# 	58.2% complete'
#
#
# 	58.3% complete'
#
#
# 	58.3% complete'
#
#
# 	58.4% complete'
#
#
# 	58.5% complete'
#
#
# 	58.6% complete'
#
#
# 	58.6% complete'
#
#
# 	58.7% complete'
#
#
# 	58.8% complete'
#
#
# 	58.9% complete'
#
#
# 	58.9% complete'
#
#
# 	59.0% complete'
#
#
# 	59.1% complete'
#
#
# 	59.2% complete'
#
#
# 	59.2% complete'
#
#
# 	59.3% complete'
#
#
# 	59.4% complete'
#
#
# 	59.5% complete'
#
#
# 	59.5% complete'
#
#
# 	59.6% complete'
#
#
# 	59.7% complete'
#
#
# 	59.8% complete'
#
#
# 	59.8% complete'
#
#
# 	59.9% complete'
#
#
# 	60.0% complete'
#
#
# 	60.1% complete'
#
#
# 	60.1% complete'
#
#
# 	60.2% complete'
#
#
# 	60.3% complete'
#
#
# 	60.3% complete'
#
#
# 	60.4% complete'
#
#
# 	60.5% complete'
#
#
# 	60.6% complete'
#
#
# 	60.6% complete'
#
#
# 	60.7% complete'
#
#
# 	60.8% complete'
#
#
# 	60.9% complete'
#
#
# 	60.9% complete'
#
#
# 	61.0% complete'
#
#
# 	61.1% complete'
#
#
# 	61.2% complete'
#
#
# 	61.2% complete'
#
#
# 	61.3% complete'
#
#
# 	61.4% complete'
#
#
# 	61.5% complete'
#
#
# 	61.5% complete'
#
#
# 	61.6% complete'
#
#
# 	61.7% complete'
#
#
# 	61.8% complete'
#
#
# 	61.8% complete'
#
#
# 	61.9% complete'
#
#
# 	62.0% complete'
#
#
# 	62.1% complete'
#
#
# 	62.1% complete'
#
#
# 	62.2% complete'
#
#
# 	62.3% complete'
#
#
# 	62.4% complete'
#
#
# 	62.4% complete'
#
#
# 	62.5% complete'
#
#
# 	62.6% complete'
#
#
# 	62.7% complete'
#
#
# 	62.7% complete'
#
#
# 	62.8% complete'
#
#
# 	62.9% complete'
#
#
# 	63.0% complete'
#
#
# 	63.0% complete'
#
#
# 	63.1% complete'
#
#
# 	63.2% complete'
#
#
# 	63.3% complete'
#
#
# 	63.3% complete'
#
#
# 	63.4% complete'
#
#
# 	63.5% complete'
#
#
# 	63.6% complete'
#
#
# 	63.6% complete'
#
#
# 	63.7% complete'
#
#
# 	63.8% complete'
#
#
# 	63.9% complete'
#
#
# 	63.9% complete'
#
#
# 	64.0% complete'
#
#
# 	64.1% complete'
#
#
# 	64.2% complete'
#
#
# 	64.2% complete'
#
#
# 	64.3% complete'
#
#
# 	64.4% complete'
#
#
# 	64.5% complete'
#
#
# 	64.5% complete'
#
#
# 	64.6% complete'
#
#
# 	64.7% complete'
#
#
# 	64.8% complete'
#
#
# 	64.8% complete'
#
#
# 	64.9% complete'
# 	65.0% complete'
#
#
# 	65.0% complete'
#
#
# 	65.1% complete'
#
#
# 	65.2% complete'
#
#
# 	65.3% complete'
#
#
# 	65.3% complete'
#
#
# 	65.4% complete'
#
#
# 	65.5% complete'
#
#
# 	65.6% complete'
#
#
# 	65.6% complete'
#
#
# 	65.7% complete'
#
#
# 	65.8% complete'
#
#
# 	65.9% complete'
#
#
# 	65.9% complete'
#
#
# 	66.0% complete'
#
#
# 	66.1% complete'
#
#
# 	66.2% complete'
#
#
# 	66.2% complete'
#
#
# 	66.3% complete'
#
#
# 	66.4% complete'
#
#
# 	66.5% complete'
#
#
# 	66.5% complete'
#
#
# 	66.6% complete'
#
#
# 	66.7% complete'
#
#
# 	66.8% complete'
#
#
# 	66.8% complete'
#
#
# 	66.9% complete'
#
#
# 	67.0% complete'
#
#
# 	67.1% complete'
#
#
# 	67.1% complete'
#
#
# 	67.2% complete'
#
#
# 	67.3% complete'
#
#
# 	67.4% complete'
#
#
# 	67.4% complete'
#
#
# 	67.5% complete'
#
#
# 	67.6% complete'
#
#
# 	67.7% complete'
#
#
# 	67.7% complete'
#
#
# 	67.8% complete'
#
#
# 	67.9% complete'
#
#
# 	68.0% complete'
#
#
# 	68.0% complete'
#
#
# 	68.1% complete'
#
#
# 	68.2% complete'
#
#
# 	68.3% complete'
#
#
# 	68.3% complete'
#
#
# 	68.4% complete'
#
#
# 	68.5% complete'
#
#
# 	68.6% complete'
#
#
# 	68.6% complete'
#
#
# 	68.7% complete'
#
#
# 	68.8% complete'
#
#
# 	68.9% complete'
#
#
# 	68.9% complete'
#
#
# 	69.0% complete'
#
#
# 	69.1% complete'
#
#
# 	69.2% complete'
#
#
# 	69.2% complete'
#
#
# 	69.3% complete'
#
#
# 	69.4% complete'
#
#
# 	69.5% complete'
#
#
# 	69.5% complete'
#
#
# 	69.6% complete'
#
#
# 	69.7% complete'
#
#
# 	69.7% complete'
#
#
# 	69.8% complete'
#
#
# 	69.9% complete'
#
#
# 	70.0% complete'
#
#
# 	70.0% complete'
#
#
# 	70.1% complete'
#
#
# 	70.2% complete'
#
#
# 	70.3% complete'
#
#
# 	70.3% complete'
#
#
# 	70.4% complete'
#
#
# 	70.5% complete'
#
#
# 	70.6% complete'
#
#
# 	70.6% complete'
#
#
# 	70.7% complete'
#
#
# 	70.8% complete'
#
#
# 	70.9% complete'
#
#
# 	70.9% complete'
#
#
# 	71.0% complete'
#
#
# 	71.1% complete'
#
#
# 	71.2% complete'
#
#
# 	71.2% complete'
#
#
# 	71.3% complete'
#
#
# 	71.4% complete'
#
#
# 	71.5% complete'
#
#
# 	71.5% complete'
#
#
# 	71.6% complete'
#
#
# 	71.7% complete'
#
#
# 	71.8% complete'
#
#
# 	71.8% complete'
#
#
# 	71.9% complete'
#
#
# 	72.0% complete'
#
#
# 	72.1% complete'
#
#
# 	72.1% complete'
#
#
# 	72.2% complete'
#
#
# 	72.3% complete'
#
#
# 	72.4% complete'
#
#
# 	72.4% complete'
#
#
# 	72.5% complete'
#
#
# 	72.6% complete'
#
#
# 	72.7% complete'
#
#
# 	72.7% complete'
#
#
# 	72.8% complete'
#
#
# 	72.9% complete'
#
#
# 	73.0% complete'
#
#
# 	73.0% complete'
#
#
# 	73.1% complete'
#
#
# 	73.2% complete'
#
#
# 	73.3% complete'
#
#
# 	73.3% complete'
#
#
# 	73.4% complete'
#
#
# 	73.5% complete'
#
#
# 	73.6% complete'
#
#
# 	73.6% complete'
#
#
# 	73.7% complete'
#
#
# 	73.8% complete'
#
#
# 	73.9% complete'
#
#
# 	73.9% complete'
#
#
# 	74.0% complete'
#
#
# 	74.1% complete'
#
#
# 	74.2% complete'
#
#
# 	74.2% complete'
#
#
# 	74.3% complete'
#
#
# 	74.4% complete'
#
#
# 	74.4% complete'
#
#
# 	74.5% complete'
#
#
# 	74.6% complete'
#
#
# 	74.7% complete'
#
#
# 	74.7% complete'
#
#
# 	74.8% complete'
#
#
# 	74.9% complete'
#
#
# 	75.0% complete'
#
#
# 	75.0% complete'
#
#
# 	75.1% complete'
#
#
# 	75.2% complete'
#
#
# 	75.3% complete'
#
#
# 	75.3% complete'
#
#
# 	75.4% complete'
#
#
# 	75.5% complete'
#
#
# 	75.6% complete'
#
#
# 	75.6% complete'
#
#
# 	75.7% complete'
#
#
# 	75.8% complete'
#
#
# 	75.9% complete'
#
#
# 	75.9% complete'
#
#
# 	76.0% complete'
#
#
# 	76.1% complete'
#
#
# 	76.2% complete'
#
#
# 	76.2% complete'
#
#
# 	76.3% complete'
#
#
# 	76.4% complete'
#
#
# 	76.5% complete'
#
#
# 	76.5% complete'
#
#
# 	76.6% complete'
#
#
# 	76.7% complete'
#
#
# 	76.8% complete'
#
#
# 	76.8% complete'
#
#
# 	76.9% complete'
#
#
# 	77.0% complete'
#
#
# 	77.1% complete'
#
#
# 	77.1% complete'
#
#
# 	77.2% complete'
#
#
# 	77.3% complete'
#
#
# 	77.4% complete'
#
#
# 	77.4% complete'
#
#
# 	77.5% complete'
#
#
# 	77.6% complete'
#
#
# 	77.7% complete'
#
#
# 	77.7% complete'
#
#
# 	77.8% complete'
#
#
# 	77.9% complete'
#
#
# 	78.0% complete'
#
#
# 	78.0% complete'
#
#
# 	78.1% complete'
#
#
# 	78.2% complete'
#
#
# 	78.3% complete'
#
#
# 	78.3% complete'
#
#
# 	78.4% complete'
#
#
# 	78.5% complete'
#
#
# 	78.6% complete'
#
#
# 	78.6% complete'
#
#
# 	78.7% complete'
#
#
# 	78.8% complete'
#
#
# 	78.8% complete'
#
#
# 	78.9% complete'
#
#
# 	79.0% complete'
#
#
# 	79.1% complete'
#
#
# 	79.1% complete'
#
#
# 	79.2% complete'
#
#
# 	79.3% complete'
#
#
# 	79.4% complete'
#
#
# 	79.4% complete'
#
#
# 	79.5% complete'
#
#
# 	79.6% complete'
#
#
# 	79.7% complete'
#
#
# 	79.7% complete'
#
#
# 	79.8% complete'
#
#
# 	79.9% complete'
#
#
# 	80.0% complete'
#
#
# 	80.0% complete'
#
#
# 	80.1% complete'
#
#
# 	80.2% complete'
#
#
# 	80.3% complete'
#
#
# 	80.3% complete'
#
#
# 	80.4% complete'
#
#
# 	80.5% complete'
#
#
# 	80.6% complete'
#
#
# 	80.6% complete'
#
#
# 	80.7% complete'
#
#
# 	80.8% complete'
#
#
# 	80.9% complete'
#
#
# 	80.9% complete'
#
#
# 	81.0% complete'
#
#
# 	81.1% complete'
#
#
# 	81.2% complete'
#
#
# 	81.2% complete'
#
#
# 	81.3% complete'
#
#
# 	81.4% complete'
#
#
# 	81.5% complete'
#
#
# 	81.5% complete'
#
#
# 	81.6% complete'
#
#
# 	81.7% complete'
#
#
# 	81.8% complete'
#
#
# 	81.8% complete'
#
#
# 	81.9% complete'
#
#
# 	82.0% complete'
#
#
# 	82.1% complete'
#
#
# 	82.1% complete'
#
#
# 	82.2% complete'
#
#
# 	82.3% complete'
#
#
# 	82.4% complete'
#
#
# 	82.4% complete'
#
#
# 	82.5% complete'
#
#
# 	82.6% complete'
#
#
# 	82.7% complete'
#
#
# 	82.7% complete'
#
#
# 	82.8% complete'
#
#
# 	82.9% complete'
#
#
# 	83.0% complete'
#
#
# 	83.0% complete'
#
#
# 	83.1% complete'
#
#
# 	83.2% complete'
#
#
# 	83.3% complete'
#
#
# 	83.3% complete'
#
#
# 	83.4% complete'
#
#
# 	83.5% complete'
#
#
# 	83.5% complete'
#
#
# 	83.6% complete'
#
#
# 	83.7% complete'
#
#
# 	83.8% complete'
#
#
# 	83.8% complete'
#
#
# 	83.9% complete'
#
#
# 	84.0% complete'
#
#
# 	84.1% complete'
#
#
# 	84.1% complete'
#
#
# 	84.2% complete'
#
#
# 	84.3% complete'
#
#
# 	84.4% complete'
#
#
# 	84.4% complete'
#
#
# 	84.5% complete'
#
#
# 	84.6% complete'
#
#
# 	84.7% complete'
#
#
# 	84.7% complete'
#
#
# 	84.8% complete'
#
#
# 	84.9% complete'
#
#
# 	85.0% complete'
#
#
# 	85.0% complete'
#
#
# 	85.1% complete'
#
#
# 	85.2% complete'
#
#
# 	85.3% complete'
#
#
# 	85.3% complete'
#
#
# 	85.4% complete'
#
#
# 	85.5% complete'
#
#
# 	85.6% complete'
#
#
# 	85.6% complete'
#
#
# 	85.7% complete'
#
#
# 	85.8% complete'
#
#
# 	85.9% complete'
#
#
# 	85.9% complete'
#
#
# 	86.0% complete'
#
#
# 	86.1% complete'
#
#
# 	86.2% complete'
#
#
# 	86.2% complete'
#
#
# 	86.3% complete'
#
#
# 	86.4% complete'
#
#
# 	86.5% complete'
#
#
# 	86.5% complete'
#
#
# 	86.6% complete'
#
#
# 	86.7% complete'
#
#
# 	86.8% complete'
#
#
# 	86.8% complete'
#
#
# 	86.9% complete'
#
#
# 	87.0% complete'
#
#
# 	87.1% complete'
#
#
# 	87.1% complete'
#
#
# 	87.2% complete'
#
#
# 	87.3% complete'
#
#
# 	87.4% complete'
#
#
# 	87.4% complete'
#
#
# 	87.5% complete'
#
#
# 	87.6% complete'
#
#
# 	87.7% complete'
#
#
# 	87.7% complete'
#
#
# 	87.8% complete'
#
#
# 	87.9% complete'
#
#
# 	88.0% complete'
#
#
# 	88.0% complete'
#
#
# 	88.1% complete'
#
#
# 	88.2% complete'
#
#
# 	88.2% complete'
#
#
# 	88.3% complete'
#
#
# 	88.4% complete'
#
#
# 	88.5% complete'
#
#
# 	88.5% complete'
#
#
# 	88.6% complete'
#
#
# 	88.7% complete'
#
#
# 	88.8% complete'
#
#
# 	88.8% complete'
#
#
# 	88.9% complete'
#
#
# 	89.0% complete'
#
#
# 	89.1% complete'
#
#
# 	89.1% complete'
#
#
# 	89.2% complete'
#
#
# 	89.3% complete'
#
#
# 	89.4% complete'
#
#
# 	89.4% complete'
#
#
# 	89.5% complete'
#
#
# 	89.6% complete'
#
#
# 	89.7% complete'
#
#
# 	89.7% complete'
#
#
# 	89.8% complete'
#
#
# 	89.9% complete'
#
#
# 	90.0% complete'
#
#
# 	90.0% complete'
#
#
# 	90.1% complete'
#
#
# 	90.2% complete'
#
#
# 	90.3% complete'
#
#
# 	90.3% complete'
#
#
# 	90.4% complete'
#
#
# 	90.5% complete'
#
#
# 	90.6% complete'
#
#
# 	90.6% complete'
#
#
# 	90.7% complete'
#
#
# 	90.8% complete'
#
#
# 	90.9% complete'
#
#
# 	90.9% complete'
#
#
# 	91.0% complete'
#
#
# 	91.1% complete'
#
#
# 	91.2% complete'
#
#
# 	91.2% complete'
#
#
# 	91.3% complete'
#
#
# 	91.4% complete'
#
#
# 	91.5% complete'
#
#
# 	91.5% complete'
#
#
# 	91.6% complete'
#
#
# 	91.7% complete'
#
#
# 	91.8% complete'
#
#
# 	91.8% complete'
#
#
# 	91.9% complete'
#
#
# 	92.0% complete'
#
#
# 	92.1% complete'
#
#
# 	92.1% complete'
#
#
# 	92.2% complete'
#
#
# 	92.3% complete'
#
#
# 	92.4% complete'
#
#
# 	92.4% complete'
#
#
# 	92.5% complete'
#
#
# 	92.6% complete'
#
#
# 	92.7% complete'
#
#
# 	92.7% complete'
#
#
# 	92.8% complete'
#
#
# 	92.9% complete'
#
#
# 	92.9% complete'
#
#
# 	93.0% complete'
#
#
# 	93.1% complete'
#
#
# 	93.2% complete'
#
#
# 	93.2% complete'
#
#
# 	93.3% complete'
#
#
# 	93.4% complete'
#
#
# 	93.5% complete'
#
#
# 	93.5% complete'
#
#
# 	93.6% complete'
#
#
# 	93.7% complete'
#
#
# 	93.8% complete'
#
#
# 	93.8% complete'
#
#
# 	93.9% complete'
#
#
# 	94.0% complete'
#
#
# 	94.1% complete'
#
#
# 	94.1% complete'
#
#
# 	94.2% complete'
#
#
# 	94.3% complete'
#
#
# 	94.4% complete'
#
#
# 	94.4% complete'
#
#
# 	94.5% complete'
#
#
# 	94.6% complete'
#
#
# 	94.7% complete'
#
#
# 	94.7% complete'
#
#
# 	94.8% complete'
#
#
# 	94.9% complete'
#
#
# 	95.0% complete'
#
#
# 	95.0% complete'
#
#
# 	95.1% complete'
#
#
# 	95.2% complete'
#
#
# 	95.3% complete'
#
#
# 	95.3% complete'
#
#
# 	95.4% complete'
#
#
# 	95.5% complete'
#
#
# 	95.6% complete'
#
#
# 	95.6% complete'
#
#
# 	95.7% complete'
#
#
# 	95.8% complete'
#
#
# 	95.9% complete'
#
#
# 	95.9% complete'
#
#
# 	96.0% complete'
#
#
# 	96.1% complete'
#
#
# 	96.2% complete'
#
#
# 	96.2% complete'
#
#
# 	96.3% complete'
#
#
# 	96.4% complete'
#
#
# 	96.5% complete'
#
#
# 	96.5% complete'
#
#
# 	96.6% complete'
#
#
# 	96.7% complete'
#
#
# 	96.8% complete'
#
#
# 	96.8% complete'
#
#
# 	96.9% complete'
#
#
# 	97.0% complete'
#
#
# 	97.1% complete'
#
#
# 	97.1% complete'
# 	97.2% complete'
#
#
# 	97.3% complete'
#
#
# 	97.3% complete'
#
#
# 	97.4% complete'
#
#
# 	97.5% complete'
#
#
# 	97.6% complete'
#
#
# 	97.6% complete'
#
#
# 	97.7% complete'
#
#
# 	97.8% complete'
#
#
# 	97.9% complete'
#
#
# 	97.9% complete'
#
#
# 	98.0% complete'
#
#
# 	98.1% complete'
#
#
# 	98.2% complete'
#
#
# 	98.2% complete'
#
#
# 	98.3% complete'
#
#
# 	98.4% complete'
#
#
# 	98.5% complete'
#
#
# 	98.5% complete'
#
#
# 	98.6% complete'
#
#
# 	98.7% complete'
#
#
# 	98.8% complete'
#
#
# 	98.8% complete'
#
#
# 	98.9% complete'
#
#
# 	99.0% complete'
#
#
# 	99.1% complete'
#
#
# 	99.1% complete'
#
#
# 	99.2% complete'
#
#
# 	99.3% complete'
#
#
# 	99.4% complete'
#
#
# 	99.4% complete'
#
#
# 	99.5% complete'
#
#
# 	99.6% complete'
#
#
# 	99.7% complete'
#
#
# 	99.7% complete'
#
#
# 	99.8% complete'
#
#
# 	99.9% complete'
#
#
# 	100.0% complete'

# %%
# UNCOMMENT TO LOAD SAVED GLOBAL FITTED TS DATA:

# load saved data and reshape it from 2d to 3d
ts_arr_2d = np.loadtxt(os.path.join(data_dir, 'fitted_ts_array_%s%s.txt' % (dataset, mask_filename_ext)))
ts_arr = ts_arr_2d.reshape(ts_arr_2d.shape[0],
                           ts_arr_2d.shape[1] // coeffs.shape[2],
                           coeffs.shape[2])

# get coords arrays
X, Y = np.meshgrid(coeffs.x, coeffs.y)

# %%
#########
# RUN EOF
#########

# calculate weights array requested
if lat_weights == 'cos':
    weights = np.cos(np.deg2rad(Y))
    weights /= weights.mean()
elif lat_weights == 'sqrt_cos':
    weights = np.sqrt(np.cos(np.deg2rad(Y)))
    weights /= weights.mean()
else:
    weights = None


# coerce ts array to rio xarray obj
ts_da = xr.DataArray([coeffs[0,:,:]*np.nan]*365) 
ts_da.attrs = coeffs.attrs
ts_da.attrs['long_name'] = ['d%i' % i for i in range(1, 366)]
ts_da = ts_da.rename({'dim_0': 'time',
                      'dim_1': 'y',
                      'dim_2': 'x',
                      })
ts_da = ts_da.assign_coords({'time': range(1, 366),
                             'y': coeffs.y.values,
                             'x': coeffs.x.values,
                             })
ts_da = ts_da.rio.write_crs(4326)
ts_da.rio.set_crs(4326)
ts_da.loc[:,:,:] = ts_arr

# use empirical orthogonal functions to collapse global ts into
# main modes of variation
solver = Eof(ts_da, weights=weights)

# %%
# grab the first n EOFs
# (and swap axes so that 3rd axis is of length neofs, to facilitate image
# plotting)
eofs = solver.eofsAsCorrelation(neofs=neofs)

# grab the PCs
pcs = solver.pcs(npcs=neofs, pcscaling=1)

# grab pct variances of EOFs
var_pcts = solver.varianceFraction(neofs)

# reconstruct the field using just the selected top EOFs
ts_recon = solver.reconstructedField(neofs)

# write eofs to file, if requested
if save_res:
    tif_filename = '%s_%s_%i_EOFs_%s%s%s.tif' % (dataset,
                                                 region_name,
                                                 neofs,
                                                 lat_weights + 'wts',
                                                 '_normts' * normalize_ts,
                                                 mask_filename_ext,
                                                  )
    eof_res_for_file = eofs.to_dataset('mode')
    eof_res_for_file = eof_res_for_file.rename_vars(
                                    {i: 'eof%i' % i for i in range(neofs)})
    eof_res_for_file.rio.to_raster(os.path.join(data_dir, tif_filename),
                       dtype=np.float32,
                       tags={'eof%i_pctvar' % i:
                             str(var_pcts.values[i]) for i in range(neofs)},
                      )

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
eofs.sel(mode=1).plot.imshow(ax=ax)

# %%
fig, ax = plt.subplots(1,1)
ax.plot(solver.varianceFraction(10)*100)
ax.set_title('pct variance explained by first 10 EOFs')
ax.set_xlabel('EOF number')
ax.set_ylabel('pct variance explained')
print([*solver.varianceFraction(10).values*100])

# %%
#########################################################################
# MAP AND PLOT CHARACTERISTIC SEASONAL PATTERNS AT ENDS OF EACH EOF RANGE
#########################################################################

fig = plt.figure(figsize=(12,9))
gs = fig.add_gridspec(nrows=neofs, ncols=5, width_ratios=[1,0.3,1,0.3,1])
for neof in range(neofs):
    ax_map = fig.add_subplot(gs[neof, 0])
    eofs.sel(mode=neof).plot.imshow(ax=ax_map)
    ax_map.set_aspect('equal')
    ax_map.set_xticks(())
    ax_map.set_yticks(())
    ax_map.set_xticklabels(())
    ax_map.set_yticklabels(())
    ax_map.set_ylabel('mode %i' % neof, fontdict={'fontsize': 20})
    ax_map.set_title('%0.1f%% of variation' % (var_pcts[neof]*100))
    ax_pc_plot = fig.add_subplot(gs[neof,2])
    ax_pc_plot.set_xlabel('time of year')
    ax_pc_plot.set_xticks(np.linspace(0, 365, 5), ['Jan', 'Apr', 'Jul',
                                                   'Oct', 'Jan'])
    pcs.sel(mode=neof).plot(ax=ax_pc_plot)
    ax_pc_plot.set_title('annual variation')
    ax_pc_plot.set_ylabel('scaled PC value')
    ax_examp_ts = fig.add_subplot(gs[neof,4])
    top_ts = ts_recon.values[:,
        eofs.sel(mode=neof)>=np.nanpercentile(eofs.sel(mode=neof), ts_top_pctile)].T
    idxs_to_plot = np.random.choice(range(top_ts.shape[0]), size=n_ts_to_plot, replace=False)
    ts_to_plot = top_ts[idxs_to_plot,:]
    for ts in ts_to_plot:
        ax_examp_ts.plot(range(365), ts, alpha=0.05, color='#850c10')
    bot_ts = ts_recon.values[:,
        eofs.sel(mode=neof)<=np.nanpercentile(eofs.sel(mode=neof), ts_bot_pctile)].T
    idxs_to_plot = np.random.choice(range(bot_ts.shape[0]), size=n_ts_to_plot, replace=False)
    ts_to_plot = bot_ts[idxs_to_plot,:]
    for ts in ts_to_plot:
        ax_examp_ts.plot(range(365), ts, alpha=0.05, color='#0b489e')
    ax_examp_ts.set_xlabel('time of year')
    ax_examp_ts.set_ylabel('scaled magnitude')
    ax_examp_ts.set_title(('seasonality at 95th pctile (red)\n'
                        'and 5th pctile (blue) of mode %i pixels') % neof)
    ax_examp_ts.set_xticks(np.linspace(0, 365, 5), ['Jan', 'Apr', 'Jul',
                                                    'Oct', 'Jan'])
fig.subplots_adjust(left=subplots_adj_left,
                     bottom=subplots_adj_bottom,
                     right=subplots_adj_right,
                     top=subplots_adj_top,
                     wspace=subplots_adj_wspace,
                     hspace=subplots_adj_hspace)
fig.show()
if save_res:
    fig_filename = '%s_%s_EOF_results_scat_%s%s%s.png' % (dataset,
                                                            region_name,
                                                            lat_weights + 'wts',
                                                            '_normts' * normalize_ts,
                                                            mask_filename_ext,
                                                           )
    fig.savefig(os.path.join(data_dir, fig_filename), dpi=500)

# %%
##################################### 
# USE HVPLOT FOR INTERACTIVE PLOTTING
##################################### 

eofs4 = solver.eofsAsCorrelation(neofs=4)
if interactive:

    # plot top 3 EOFs as RGB image
    rgb_plot = eofs4[1:].hvplot.rgb(x='x', y='y', bands='mode',
                               geo=True,
                               #coastlines=True,
                               alpha=0.4,
                               #responsive=True,
                               width=800,
                               height=600,
                               title='top 3 EOFs in R, G, B channels',
                               tiles='EsriReference',
                               data_aspect=1)
    pn.serve(rgb_plot)
else:
    fig2 = plt.figure(figsize=(16,8))
    ax_rgb = fig2.add_subplot(111)
    eofs4[1:].plot.imshow(ax=ax_rgb)
    fig2.show()
