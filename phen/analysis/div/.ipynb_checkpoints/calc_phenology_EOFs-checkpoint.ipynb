# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio as rio
#import cartopy.crs as crs
#import panel as pn
#import hvplot.xarray
from rasterio.plot import reshape_as_raster
import xarray as xr
import rioxarray as rxr
import os
import datetime
import daylight
import pytz
from shapely.geometry import Point
from scipy.signal import argrelextrema
from scipy.optimize import curve_fit
from scipy.interpolate import griddata
from sklearn.manifold import MDS
from sklearn.preprocessing import normalize
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from eofs.xarray import Eof
# Out:
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
# import rpy2
# import pyEOF

# %%
# dataset params
dataset = 'NIRv'
#dataset = 'SIF'
masking_mode = 'default'
#masking_mode = 'strict'
mask_filename_ext_dict = {'strict': '_STRICTMASK',
                          'default': ''}
mask_filename_ext = mask_filename_ext_dict[masking_mode]

# %%
# plotting params
subplots_adj_left=0.05
subplots_adj_bottom=0.1
subplots_adj_right=0.95
subplots_adj_top=0.9
subplots_adj_wspace=0.2
subplots_adj_hspace=0.4

# %%
# NOTE on memory requirements
    #        I estimate that the global 365 x 2400 x 6900 raster will take up
    #       about 46.1 GB memory;
    #       (NOTE: I could also cast of dtype float32 and cut down to ~23 GB,
    #              for 'safety' sake)
    #       if I ran this on savio bigmem that would only be ~1/9th total RAM,
    #       so it should be doable to create a giant global 365 x 2400 x 6900
    #       numpy array and then fill it with all fitted time series and write
    #       to disk, though that's only ~1/2 RAM on savio3, so first just try
    #       there!
    #       then I could separately read in as a dask array and run EOF
    #       analysis on that, I believe.
    #       though I wonder if I could just run the EOF analysis within that
    #       same job. Not sure how much memory requirement expands as factor
    #       of size of base spatiotemporal dataset, and not easily finding that
    #       informiation on line...


# TODO:

    # could use clustering afterward, with scree plot, to determine k
    # distinct 'classes' of global phenological seasonality 'types'

# %%
! ls /global/scratch/users/drewhart/seasonality/GEE_outputs/NIRv
# Out:
# global_seas_R2_NIRv.tif			global_seas_coeffs_NIRv-00093.tfrecord
# global_seas_coeffs_NIRv-00000.tfrecord	global_seas_coeffs_NIRv-00094.tfrecord
# global_seas_coeffs_NIRv-00001.tfrecord	global_seas_coeffs_NIRv-00095.tfrecord
# global_seas_coeffs_NIRv-00002.tfrecord	global_seas_coeffs_NIRv-00096.tfrecord
# global_seas_coeffs_NIRv-00003.tfrecord	global_seas_coeffs_NIRv-00097.tfrecord
# global_seas_coeffs_NIRv-00004.tfrecord	global_seas_coeffs_NIRv-00098.tfrecord
# global_seas_coeffs_NIRv-00005.tfrecord	global_seas_coeffs_NIRv-00099.tfrecord
# global_seas_coeffs_NIRv-00006.tfrecord	global_seas_coeffs_NIRv-00100.tfrecord
# global_seas_coeffs_NIRv-00007.tfrecord	global_seas_coeffs_NIRv-00101.tfrecord
# global_seas_coeffs_NIRv-00008.tfrecord	global_seas_coeffs_NIRv-00102.tfrecord
# global_seas_coeffs_NIRv-00009.tfrecord	global_seas_coeffs_NIRv-00103.tfrecord
# global_seas_coeffs_NIRv-00010.tfrecord	global_seas_coeffs_NIRv-00104.tfrecord
# global_seas_coeffs_NIRv-00011.tfrecord	global_seas_coeffs_NIRv-00105.tfrecord
# global_seas_coeffs_NIRv-00012.tfrecord	global_seas_coeffs_NIRv-00106.tfrecord
# global_seas_coeffs_NIRv-00013.tfrecord	global_seas_coeffs_NIRv-00107.tfrecord
# global_seas_coeffs_NIRv-00014.tfrecord	global_seas_coeffs_NIRv-00108.tfrecord
# global_seas_coeffs_NIRv-00015.tfrecord	global_seas_coeffs_NIRv-00109.tfrecord
# global_seas_coeffs_NIRv-00016.tfrecord	global_seas_coeffs_NIRv-00110.tfrecord
# global_seas_coeffs_NIRv-00017.tfrecord	global_seas_coeffs_NIRv-00111.tfrecord
# global_seas_coeffs_NIRv-00018.tfrecord	global_seas_coeffs_NIRv-00112.tfrecord
# global_seas_coeffs_NIRv-00019.tfrecord	global_seas_coeffs_NIRv-00113.tfrecord
# global_seas_coeffs_NIRv-00020.tfrecord	global_seas_coeffs_NIRv-00114.tfrecord
# global_seas_coeffs_NIRv-00021.tfrecord	global_seas_coeffs_NIRv-00115.tfrecord
# global_seas_coeffs_NIRv-00022.tfrecord	global_seas_coeffs_NIRv-00116.tfrecord
# global_seas_coeffs_NIRv-00023.tfrecord	global_seas_coeffs_NIRv-00117.tfrecord
# global_seas_coeffs_NIRv-00024.tfrecord	global_seas_coeffs_NIRv-00118.tfrecord
# global_seas_coeffs_NIRv-00025.tfrecord	global_seas_coeffs_NIRv-00119.tfrecord
# global_seas_coeffs_NIRv-00026.tfrecord	global_seas_coeffs_NIRv-00120.tfrecord
# global_seas_coeffs_NIRv-00027.tfrecord	global_seas_coeffs_NIRv-00121.tfrecord
# global_seas_coeffs_NIRv-00028.tfrecord	global_seas_coeffs_NIRv-00122.tfrecord
# global_seas_coeffs_NIRv-00029.tfrecord	global_seas_coeffs_NIRv-00123.tfrecord
# global_seas_coeffs_NIRv-00030.tfrecord	global_seas_coeffs_NIRv-00124.tfrecord
# global_seas_coeffs_NIRv-00031.tfrecord	global_seas_coeffs_NIRv-00125.tfrecord
# global_seas_coeffs_NIRv-00032.tfrecord	global_seas_coeffs_NIRv-00126.tfrecord
# global_seas_coeffs_NIRv-00033.tfrecord	global_seas_coeffs_NIRv-00127.tfrecord
# global_seas_coeffs_NIRv-00034.tfrecord	global_seas_coeffs_NIRv-00128.tfrecord
# global_seas_coeffs_NIRv-00035.tfrecord	global_seas_coeffs_NIRv-00129.tfrecord
# global_seas_coeffs_NIRv-00036.tfrecord	global_seas_coeffs_NIRv-00130.tfrecord
# global_seas_coeffs_NIRv-00037.tfrecord	global_seas_coeffs_NIRv-00131.tfrecord
# global_seas_coeffs_NIRv-00038.tfrecord	global_seas_coeffs_NIRv-00132.tfrecord
# global_seas_coeffs_NIRv-00039.tfrecord	global_seas_coeffs_NIRv-00133.tfrecord
# global_seas_coeffs_NIRv-00040.tfrecord	global_seas_coeffs_NIRv-00134.tfrecord
# global_seas_coeffs_NIRv-00041.tfrecord	global_seas_coeffs_NIRv-00135.tfrecord
# global_seas_coeffs_NIRv-00042.tfrecord	global_seas_coeffs_NIRv-00136.tfrecord
# global_seas_coeffs_NIRv-00043.tfrecord	global_seas_coeffs_NIRv-00137.tfrecord
# global_seas_coeffs_NIRv-00044.tfrecord	global_seas_coeffs_NIRv-00138.tfrecord
# global_seas_coeffs_NIRv-00045.tfrecord	global_seas_coeffs_NIRv-00139.tfrecord
# global_seas_coeffs_NIRv-00046.tfrecord	global_seas_coeffs_NIRv-00140.tfrecord
# global_seas_coeffs_NIRv-00047.tfrecord	global_seas_coeffs_NIRv-00141.tfrecord
# global_seas_coeffs_NIRv-00048.tfrecord	global_seas_coeffs_NIRv-00142.tfrecord
# global_seas_coeffs_NIRv-00049.tfrecord	global_seas_coeffs_NIRv-00143.tfrecord
# global_seas_coeffs_NIRv-00050.tfrecord	global_seas_coeffs_NIRv-00144.tfrecord
# global_seas_coeffs_NIRv-00051.tfrecord	global_seas_coeffs_NIRv-00145.tfrecord
# global_seas_coeffs_NIRv-00052.tfrecord	global_seas_coeffs_NIRv-00146.tfrecord
# global_seas_coeffs_NIRv-00053.tfrecord	global_seas_coeffs_NIRv-00147.tfrecord
# global_seas_coeffs_NIRv-00054.tfrecord	global_seas_coeffs_NIRv-00148.tfrecord
# global_seas_coeffs_NIRv-00055.tfrecord	global_seas_coeffs_NIRv-00149.tfrecord
# global_seas_coeffs_NIRv-00056.tfrecord	global_seas_coeffs_NIRv-00150.tfrecord
# global_seas_coeffs_NIRv-00057.tfrecord	global_seas_coeffs_NIRv-00151.tfrecord
# global_seas_coeffs_NIRv-00058.tfrecord	global_seas_coeffs_NIRv-00152.tfrecord
# global_seas_coeffs_NIRv-00059.tfrecord	global_seas_coeffs_NIRv-00153.tfrecord
# global_seas_coeffs_NIRv-00060.tfrecord	global_seas_coeffs_NIRv-00154.tfrecord
# global_seas_coeffs_NIRv-00061.tfrecord	global_seas_coeffs_NIRv-00155.tfrecord
# global_seas_coeffs_NIRv-00062.tfrecord	global_seas_coeffs_NIRv-00156.tfrecord
# global_seas_coeffs_NIRv-00063.tfrecord	global_seas_coeffs_NIRv-00157.tfrecord
# global_seas_coeffs_NIRv-00064.tfrecord	global_seas_coeffs_NIRv-00158.tfrecord
# global_seas_coeffs_NIRv-00065.tfrecord	global_seas_coeffs_NIRv-00159.tfrecord
# global_seas_coeffs_NIRv-00066.tfrecord	global_seas_coeffs_NIRv-00160.tfrecord
# global_seas_coeffs_NIRv-00067.tfrecord	global_seas_coeffs_NIRv-00161.tfrecord
# global_seas_coeffs_NIRv-00068.tfrecord	global_seas_coeffs_NIRv-00162.tfrecord
# global_seas_coeffs_NIRv-00069.tfrecord	global_seas_coeffs_NIRv-00163.tfrecord
# global_seas_coeffs_NIRv-00070.tfrecord	global_seas_coeffs_NIRv-00164.tfrecord
# global_seas_coeffs_NIRv-00071.tfrecord	global_seas_coeffs_NIRv-00165.tfrecord
# global_seas_coeffs_NIRv-00072.tfrecord	global_seas_coeffs_NIRv-00166.tfrecord
# global_seas_coeffs_NIRv-00073.tfrecord	global_seas_coeffs_NIRv-00167.tfrecord
# global_seas_coeffs_NIRv-00074.tfrecord	global_seas_coeffs_NIRv-00168.tfrecord
# global_seas_coeffs_NIRv-00075.tfrecord	global_seas_coeffs_NIRv-00169.tfrecord
# global_seas_coeffs_NIRv-00076.tfrecord	global_seas_coeffs_NIRv-00170.tfrecord
# global_seas_coeffs_NIRv-00077.tfrecord	global_seas_coeffs_NIRv-00171.tfrecord
# global_seas_coeffs_NIRv-00078.tfrecord	global_seas_coeffs_NIRv-00172.tfrecord
# global_seas_coeffs_NIRv-00079.tfrecord	global_seas_coeffs_NIRv-00173.tfrecord
# global_seas_coeffs_NIRv-00080.tfrecord	global_seas_coeffs_NIRv-00174.tfrecord
# global_seas_coeffs_NIRv-00081.tfrecord	global_seas_coeffs_NIRv-00175.tfrecord
# global_seas_coeffs_NIRv-00082.tfrecord	global_seas_coeffs_NIRv-00176.tfrecord
# global_seas_coeffs_NIRv-00083.tfrecord	global_seas_coeffs_NIRv-00177.tfrecord
# global_seas_coeffs_NIRv-00084.tfrecord	global_seas_coeffs_NIRv-00178.tfrecord
# global_seas_coeffs_NIRv-00085.tfrecord	global_seas_coeffs_NIRv-00179.tfrecord
# global_seas_coeffs_NIRv-00086.tfrecord	global_seas_coeffs_NIRv-00180.tfrecord
# global_seas_coeffs_NIRv-00087.tfrecord	global_seas_coeffs_NIRv-00181.tfrecord
# global_seas_coeffs_NIRv-00088.tfrecord	global_seas_coeffs_NIRv-00182.tfrecord
# global_seas_coeffs_NIRv-00089.tfrecord	global_seas_coeffs_NIRv-00183.tfrecord
# global_seas_coeffs_NIRv-00090.tfrecord	global_seas_coeffs_NIRv-mixer.json
# global_seas_coeffs_NIRv-00091.tfrecord	global_seas_coeffs_NIRv.tif
# global_seas_coeffs_NIRv-00092.tfrecord

# %%
###################
# BEHAVIORAL PARAMS
###################

# min and max x and y values, to optionally subset analysis to a region
region_name = 'global'
min_x = None
max_x = None
min_y = None
max_y = None


# analyses to run
run_eof = True
run_mds = False

# use hvplot, etc for interactive plotting?
interactive = False

# save figures and datasets?
save_res = True

# data dir on laptop
if os.getcwd().split('/')[1] == 'home':
    data_dir = '/home/deth/Desktop/CAL/research/projects/seasonality/results/maps'
# data dir on savio
else:
    data_dir = os.path.join('/global/scratch/users/drewhart/seasonality/GEE_outputs',
                            dataset + mask_filename_ext)

# set the seed
set_seed = True
if set_seed:
    seed = 1
    np.random.seed(seed)

# normalize each ts to itself?
# NOTE: I think it makes sense to do this, since I'm only interested in timing,
#       and otherwise (especially based on Alex Turner's results in CA) I
#       expect the first EOF will largely reflect global (i.e.,
#       cross-study-area) variation in magnitude of fitted values;
#       nonetheless, setting a flag for this so that I can check that
#       expectation and check sensitivity to this decision
normalize_ts = True

# latitude weights to use?
#lat_weights = 'cos'
lat_weights = 'sqrt_cos'
#lat_weights = None

# center the data being input to EOF?
# TODO: decide about this!
center_eof = True

# number of top EOFs to use?
neofs = 4

# pctiles and counts of example time series to plot?
ts_top_pctile = 95
ts_bot_pctile = 95
n_ts_to_plot = 1000

# %%
###########
# FUNCTIONS
###########

def make_design_matrix():
    """
    Makes and returns the regression's design matrix, a 365 x 5 numpy array
    in which the columns contain, in order:
        - 1s (for the constant);
        - sin and cos of annual-harmonic days of the year
          (i.e. days are expressed in radians from 0 to 2pi);
        - sin and cos of the semiannual-harmonic days of the year
          (i.e. days are expressed in radians from 0 to 4pi).
    """
    # get 1 year of daily values, expressed in radians, 1 rotation/yr
    annual_radian_days = np.linspace(0, 2*np.pi, 366)[:365]
    # get 1 year of daily values, expressed in radians, 2 rotations/yr
    semiannual_radian_days = np.linspace(0, 4*np.pi, 366)[:365] % (2 * np.pi)
    # get the harmonic values of those
    sin1 = np.sin(annual_radian_days)
    cos1 = np.cos(annual_radian_days)
    sin2 = np.sin(semiannual_radian_days)
    cos2 = np.cos(semiannual_radian_days)
    # add a vector of 1s for the constant term, then recast as a 365 x 5 array,
    # to use as the covariate values in the regression
    design_mat = np.array([np.ones(sin1.shape), sin1, cos1, sin2, cos2]).T
    return design_mat

# %%
########################################
# READ IN COEFFS, GET ARRAY OF FITTED TS
########################################

# read global NIRv coeffs
coeffs = rxr.open_rasterio(os.path.join(data_dir, 'global_seas_coeffs_%s%s.tif' % (dataset, mask_filename_ext)))

# subset global raster to study area (if all Nones then not subsetted!)
# NOTE: max_y and min_y flipped because y res negative in CRS transform
coeffs = coeffs.sel(x=slice(min_x, max_x), y=slice(max_y, min_y))

# get coords arrays
X, Y = np.meshgrid(coeffs.x, coeffs.y)

# %%
# create empty time-series array for EOF analysis
ts_arr = np.ones((365, coeffs.shape[1], coeffs.shape[2]), dtype=np.float32) * np.nan

# make the harmonic regression's design matrix
dm = make_design_matrix()

# get the time series for each sample
# NOTE: coeffs.shape[0] == 5, one band for each regression coeff
for i in range(coeffs.shape[1]):
    for j in range(coeffs.shape[2]):
        ts = np.sum(coeffs[:, i, j].values * dm, axis=1)
        # normalize time series [0,1], if desired
        # NOTE: if not, pretty certain that first EOF will largely capture
        #       global (i.e., across full subsetted extent) variation
        #       in fitted magnitude
        if normalize_ts and not np.any(np.isnan(ts)):
            ts = normalize([ts]).flatten()
        assert ts.shape == (365,)
        ts_arr[:, i, j] = ts
    print('\n\n\t%0.3f %% complete' % (100*((i+1)/coeffs.shape[2])))

# once complete, save this to a simple numpy array file
# (for now, anyhow; might be worth saving as a big geospatial file
#  eventually?)
if save_res:
    np.savetxt(os.path.join(data_dir, 'fitted_ts_array_%s%s.txt' % (dataset, mask_filename_ext)),
            ts_arr.reshape(ts_arr.shape[0], -1))

    # load saved data and reshape it from 2d to 3d
    ts_arr_2d = np.loadtxt(os.path.join(data_dir, 'fitted_ts_array_%s%s.txt' % (dataset, mask_filename_ext)))
    ts_arr = ts_arr_2d.reshape(ts_arr_2d.shape[0],
                               ts_arr_2d.shape[1] // coeffs.shape[2],
                               coeffs.shape[2])
# Out:
# 	0.014 % complete
#
#
# 	0.029 % complete
#
#
# 	0.043 % complete
#
#
# 	0.058 % complete
#
#
# 	0.072 % complete
#
#
# 	0.087 % complete
#
#
# 	0.101 % complete
#
#
# 	0.116 % complete
#
#
# 	0.130 % complete
#
#
# 	0.145 % complete
#
#
# 	0.159 % complete
#
#
# 	0.174 % complete
#
#
# 	0.188 % complete
#
#
# 	0.203 % complete
#
#
# 	0.217 % complete
#
#
# 	0.232 % complete
#
#
# 	0.246 % complete
#
#
# 	0.261 % complete
#
#
# 	0.275 % complete
#
#
# 	0.290 % complete
#
#
# 	0.304 % complete
#
#
# 	0.319 % complete
#
#
# 	0.333 % complete
#
#
# 	0.348 % complete
#
#
# 	0.362 % complete
#
#
# 	0.377 % complete
#
#
# 	0.391 % complete
#
#
# 	0.406 % complete
#
#
# 	0.420 % complete
#
#
# 	0.435 % complete
#
#
# 	0.449 % complete
#
#
# 	0.464 % complete
#
#
# 	0.478 % complete
#
#
# 	0.493 % complete
#
#
# 	0.507 % complete
#
#
# 	0.522 % complete
#
#
# 	0.536 % complete
#
#
# 	0.551 % complete
#
#
# 	0.565 % complete
#
#
# 	0.580 % complete
#
#
# 	0.594 % complete
#
#
# 	0.609 % complete
#
#
# 	0.623 % complete
#
#
# 	0.638 % complete
#
#
# 	0.652 % complete
#
#
# 	0.667 % complete
#
#
# 	0.681 % complete
#
#
# 	0.696 % complete
#
#
# 	0.710 % complete
#
#
# 	0.725 % complete
#
#
# 	0.739 % complete
#
#
# 	0.754 % complete
#
#
# 	0.768 % complete
#
#
# 	0.783 % complete
#
#
# 	0.797 % complete
#
#
# 	0.812 % complete
#
#
# 	0.826 % complete
#
#
# 	0.841 % complete
#
#
# 	0.855 % complete
#
#
# 	0.870 % complete
#
#
# 	0.884 % complete
#
#
# 	0.899 % complete
#
#
# 	0.913 % complete
#
#
# 	0.928 % complete
#
#
# 	0.942 % complete
#
#
# 	0.957 % complete
#
#
# 	0.971 % complete
#
#
# 	0.986 % complete
#
#
# 	1.000 % complete
#
#
# 	1.014 % complete
#
#
# 	1.029 % complete
#
#
# 	1.043 % complete
#
#
# 	1.058 % complete
#
#
# 	1.072 % complete
#
#
# 	1.087 % complete
#
#
# 	1.101 % complete
#
#
# 	1.116 % complete
#
#
# 	1.130 % complete
#
#
# 	1.145 % complete
#
#
# 	1.159 % complete
#
#
# 	1.174 % complete
#
#
# 	1.188 % complete
#
#
# 	1.203 % complete
#
#
# 	1.217 % complete
#
#
# 	1.232 % complete
#
#
# 	1.246 % complete
#
#
# 	1.261 % complete
#
#
# 	1.275 % complete
#
#
# 	1.290 % complete
#
#
# 	1.304 % complete
#
#
# 	1.319 % complete
#
#
# 	1.333 % complete
#
#
# 	1.348 % complete
#
#
# 	1.362 % complete
#
#
# 	1.377 % complete
#
#
# 	1.391 % complete
#
#
# 	1.406 % complete
#
#
# 	1.420 % complete
#
#
# 	1.435 % complete
#
#
# 	1.449 % complete
#
#
# 	1.464 % complete
#
#
# 	1.478 % complete
#
#
# 	1.493 % complete
#
#
# 	1.507 % complete
#
#
# 	1.522 % complete
#
#
# 	1.536 % complete
#
#
# 	1.551 % complete
#
#
# 	1.565 % complete
#
#
# 	1.580 % complete
#
#
# 	1.594 % complete
#
#
# 	1.609 % complete
#
#
# 	1.623 % complete
#
#
# 	1.638 % complete
#
#
# 	1.652 % complete
#
#
# 	1.667 % complete
#
#
# 	1.681 % complete
#
#
# 	1.696 % complete
#
#
# 	1.710 % complete
#
#
# 	1.725 % complete
#
#
# 	1.739 % complete
#
#
# 	1.754 % complete
#
#
# 	1.768 % complete
#
#
# 	1.783 % complete
#
#
# 	1.797 % complete
#
#
# 	1.812 % complete
#
#
# 	1.826 % complete
#
#
# 	1.841 % complete
#
#
# 	1.855 % complete
#
#
# 	1.870 % complete
#
#
# 	1.884 % complete
#
#
# 	1.899 % complete
#
#
# 	1.913 % complete
#
#
# 	1.928 % complete
#
#
# 	1.942 % complete
#
#
# 	1.957 % complete
#
#
# 	1.971 % complete
#
#
# 	1.986 % complete
#
#
# 	2.000 % complete
#
#
# 	2.014 % complete
#
#
# 	2.029 % complete
#
#
# 	2.043 % complete
#
#
# 	2.058 % complete
#
#
# 	2.072 % complete
#
#
# 	2.087 % complete
#
#
# 	2.101 % complete
#
#
# 	2.116 % complete
#
#
# 	2.130 % complete
#
#
# 	2.145 % complete
#
#
# 	2.159 % complete
#
#
# 	2.174 % complete
#
#
# 	2.188 % complete
#
#
# 	2.203 % complete
#
#
# 	2.217 % complete
#
#
# 	2.232 % complete
#
#
# 	2.246 % complete
#
#
# 	2.261 % complete
#
#
# 	2.275 % complete
#
#
# 	2.290 % complete
#
#
# 	2.304 % complete
#
#
# 	2.319 % complete
#
#
# 	2.333 % complete
#
#
# 	2.348 % complete
#
#
# 	2.362 % complete
#
#
# 	2.377 % complete
#
#
# 	2.391 % complete
#
#
# 	2.406 % complete
#
#
# 	2.420 % complete
#
#
# 	2.435 % complete
#
#
# 	2.449 % complete
#
#
# 	2.464 % complete
#
#
# 	2.478 % complete
#
#
# 	2.493 % complete
#
#
# 	2.507 % complete
#
#
# 	2.522 % complete
#
#
# 	2.536 % complete
#
#
# 	2.551 % complete
#
#
# 	2.565 % complete
#
#
# 	2.580 % complete
#
#
# 	2.594 % complete
#
#
# 	2.609 % complete
#
#
# 	2.623 % complete
#
#
# 	2.638 % complete
#
#
# 	2.652 % complete
#
#
# 	2.667 % complete
#
#
# 	2.681 % complete
#
#
# 	2.696 % complete
#
#
# 	2.710 % complete
#
#
# 	2.725 % complete
#
#
# 	2.739 % complete
#
#
# 	2.754 % complete
#
#
# 	2.768 % complete
#
#
# 	2.783 % complete
#
#
# 	2.797 % complete
#
#
# 	2.812 % complete
#
#
# 	2.826 % complete
#
#
# 	2.841 % complete
#
#
# 	2.855 % complete
#
#
# 	2.870 % complete
#
#
# 	2.884 % complete
#
#
# 	2.899 % complete
#
#
# 	2.913 % complete
#
#
# 	2.928 % complete
#
#
# 	2.942 % complete
#
#
# 	2.957 % complete
#
#
# 	2.971 % complete
#
#
# 	2.986 % complete
#
#
# 	3.000 % complete
#
#
# 	3.014 % complete
#
#
# 	3.029 % complete
#
#
# 	3.043 % complete
#
#
# 	3.058 % complete
#
#
# 	3.072 % complete
#
#
# 	3.087 % complete
#
#
# 	3.101 % complete
#
#
# 	3.116 % complete
#
#
# 	3.130 % complete
#
#
# 	3.145 % complete
#
#
# 	3.159 % complete
#
#
# 	3.174 % complete
#
#
# 	3.188 % complete
#
#
# 	3.203 % complete
#
#
# 	3.217 % complete
#
#
# 	3.232 % complete
#
#
# 	3.246 % complete
#
#
# 	3.261 % complete
#
#
# 	3.275 % complete
#
#
# 	3.290 % complete
#
#
# 	3.304 % complete
#
#
# 	3.319 % complete
#
#
# 	3.333 % complete
#
#
# 	3.348 % complete
#
#
# 	3.362 % complete
#
#
# 	3.377 % complete
#
#
# 	3.391 % complete
#
#
# 	3.406 % complete
#
#
# 	3.420 % complete
#
#
# 	3.435 % complete
#
#
# 	3.449 % complete
#
#
# 	3.464 % complete
#
#
# 	3.478 % complete
#
#
# 	3.493 % complete
#
#
# 	3.507 % complete
#
#
# 	3.522 % complete
#
#
# 	3.536 % complete
#
#
# 	3.551 % complete
#
#
# 	3.565 % complete
#
#
# 	3.580 % complete
#
#
# 	3.594 % complete
#
#
# 	3.609 % complete
#
#
# 	3.623 % complete
#
#
# 	3.638 % complete
#
#
# 	3.652 % complete
#
#
# 	3.667 % complete
#
#
# 	3.681 % complete
#
#
# 	3.696 % complete
#
#
# 	3.710 % complete
#
#
# 	3.725 % complete
#
#
# 	3.739 % complete
#
#
# 	3.754 % complete
#
#
# 	3.768 % complete
#
#
# 	3.783 % complete
#
#
# 	3.797 % complete
#
#
# 	3.812 % complete
#
#
# 	3.826 % complete
#
#
# 	3.841 % complete
#
#
# 	3.855 % complete
#
#
# 	3.870 % complete
#
#
# 	3.884 % complete
#
#
# 	3.899 % complete
#
#
# 	3.913 % complete
#
#
# 	3.928 % complete
#
#
# 	3.942 % complete
#
#
# 	3.957 % complete
#
#
# 	3.971 % complete
#
#
# 	3.986 % complete
#
#
# 	4.000 % complete
#
#
# 	4.014 % complete
#
#
# 	4.029 % complete
#
#
# 	4.043 % complete
#
#
# 	4.058 % complete
#
#
# 	4.072 % complete
#
#
# 	4.087 % complete
#
#
# 	4.101 % complete
#
#
# 	4.116 % complete
#
#
# 	4.130 % complete
#
#
# 	4.145 % complete
#
#
# 	4.159 % complete
#
#
# 	4.174 % complete
#
#
# 	4.188 % complete
#
#
# 	4.203 % complete
#
#
# 	4.217 % complete
#
#
# 	4.232 % complete
#
#
# 	4.246 % complete
#
#
# 	4.261 % complete
#
#
# 	4.275 % complete
#
#
# 	4.290 % complete
#
#
# 	4.304 % complete
#
#
# 	4.319 % complete
#
#
# 	4.333 % complete
#
#
# 	4.348 % complete
#
#
# 	4.362 % complete
#
#
# 	4.377 % complete
#
#
# 	4.391 % complete
#
#
# 	4.406 % complete
#
#
# 	4.420 % complete
#
#
# 	4.435 % complete
#
#
# 	4.449 % complete
#
#
# 	4.464 % complete
#
#
# 	4.478 % complete
#
#
# 	4.493 % complete
#
#
# 	4.507 % complete
#
#
# 	4.522 % complete
#
#
# 	4.536 % complete
#
#
# 	4.551 % complete
#
#
# 	4.565 % complete
#
#
# 	4.580 % complete
#
#
# 	4.594 % complete
#
#
# 	4.609 % complete
#
#
# 	4.623 % complete
#
#
# 	4.638 % complete
#
#
# 	4.652 % complete
#
#
# 	4.667 % complete
#
#
# 	4.681 % complete
#
#
# 	4.696 % complete
#
#
# 	4.710 % complete
#
#
# 	4.725 % complete
#
#
# 	4.739 % complete
#
#
# 	4.754 % complete
#
#
# 	4.768 % complete
#
#
# 	4.783 % complete
#
#
# 	4.797 % complete
#
#
# 	4.812 % complete
#
#
# 	4.826 % complete
#
#
# 	4.841 % complete
#
#
# 	4.855 % complete
#
#
# 	4.870 % complete
#
#
# 	4.884 % complete
#
#
# 	4.899 % complete
#
#
# 	4.913 % complete
#
#
# 	4.928 % complete
#
#
# 	4.942 % complete
#
#
# 	4.957 % complete
#
#
# 	4.971 % complete
#
#
# 	4.986 % complete
#
#
# 	5.000 % complete
#
#
# 	5.014 % complete
#
#
# 	5.029 % complete
#
#
# 	5.043 % complete
#
#
# 	5.058 % complete
#
#
# 	5.072 % complete
#
#
# 	5.087 % complete
#
#
# 	5.101 % complete
#
#
# 	5.116 % complete
#
#
# 	5.130 % complete
#
#
# 	5.145 % complete
#
#
# 	5.159 % complete
#
#
# 	5.174 % complete
#
#
# 	5.188 % complete
#
#
# 	5.203 % complete
#
#
# 	5.217 % complete
#
#
# 	5.232 % complete
#
#
# 	5.246 % complete
#
#
# 	5.261 % complete
#
#
# 	5.275 % complete
#
#
# 	5.290 % complete
#
#
# 	5.304 % complete
#
#
# 	5.319 % complete
#
#
# 	5.333 % complete
#
#
# 	5.348 % complete
#
#
# 	5.362 % complete
#
#
# 	5.377 % complete
#
#
# 	5.391 % complete
#
#
# 	5.406 % complete
#
#
# 	5.420 % complete
#
#
# 	5.435 % complete
#
#
# 	5.449 % complete
#
#
# 	5.464 % complete
#
#
# 	5.478 % complete
#
#
# 	5.493 % complete
#
#
# 	5.507 % complete
#
#
# 	5.522 % complete
#
#
# 	5.536 % complete
#
#
# 	5.551 % complete
#
#
# 	5.565 % complete
#
#
# 	5.580 % complete
#
#
# 	5.594 % complete
#
#
# 	5.609 % complete
#
#
# 	5.623 % complete
#
#
# 	5.638 % complete
#
#
# 	5.652 % complete
#
#
# 	5.667 % complete
#
#
# 	5.681 % complete
#
#
# 	5.696 % complete
#
#
# 	5.710 % complete
#
#
# 	5.725 % complete
#
#
# 	5.739 % complete
#
#
# 	5.754 % complete
#
#
# 	5.768 % complete
#
#
# 	5.783 % complete
#
#
# 	5.797 % complete
#
#
# 	5.812 % complete
#
#
# 	5.826 % complete
#
#
# 	5.841 % complete
#
#
# 	5.855 % complete
#
#
# 	5.870 % complete
#
#
# 	5.884 % complete
#
#
# 	5.899 % complete
#
#
# 	5.913 % complete
#
#
# 	5.928 % complete
#
#
# 	5.942 % complete
# 	5.957 % complete
#
#
# 	5.971 % complete
#
#
# 	5.986 % complete
#
#
# 	6.000 % complete
#
#
# 	6.014 % complete
#
#
# 	6.029 % complete
#
#
# 	6.043 % complete
#
#
# 	6.058 % complete
#
#
# 	6.072 % complete
#
#
# 	6.087 % complete
#
#
# 	6.101 % complete
#
#
# 	6.116 % complete
#
#
# 	6.130 % complete
#
#
# 	6.145 % complete
#
#
# 	6.159 % complete
#
#
# 	6.174 % complete
#
#
# 	6.188 % complete
#
#
# 	6.203 % complete
#
#
# 	6.217 % complete
#
#
# 	6.232 % complete
#
#
# 	6.246 % complete
#
#
# 	6.261 % complete
#
#
# 	6.275 % complete
#
#
# 	6.290 % complete
#
#
# 	6.304 % complete
#
#
# 	6.319 % complete
#
#
# 	6.333 % complete
#
#
# 	6.348 % complete
#
#
# 	6.362 % complete
#
#
# 	6.377 % complete
#
#
# 	6.391 % complete
#
#
# 	6.406 % complete
#
#
# 	6.420 % complete
#
#
# 	6.435 % complete
#
#
# 	6.449 % complete
#
#
# 	6.464 % complete
#
#
# 	6.478 % complete
#
#
# 	6.493 % complete
#
#
# 	6.507 % complete
#
#
# 	6.522 % complete
#
#
# 	6.536 % complete
#
#
# 	6.551 % complete
#
#
# 	6.565 % complete
#
#
# 	6.580 % complete
#
#
# 	6.594 % complete
#
#
# 	6.609 % complete
#
#
# 	6.623 % complete
#
#
# 	6.638 % complete
#
#
# 	6.652 % complete
#
#
# 	6.667 % complete
#
#
# 	6.681 % complete
#
#
# 	6.696 % complete
#
#
# 	6.710 % complete
#
#
# 	6.725 % complete
#
#
# 	6.739 % complete
#
#
# 	6.754 % complete
#
#
# 	6.768 % complete
#
#
# 	6.783 % complete
#
#
# 	6.797 % complete
#
#
# 	6.812 % complete
#
#
# 	6.826 % complete
#
#
# 	6.841 % complete
#
#
# 	6.855 % complete
#
#
# 	6.870 % complete
#
#
# 	6.884 % complete
#
#
# 	6.899 % complete
#
#
# 	6.913 % complete
#
#
# 	6.928 % complete
#
#
# 	6.942 % complete
#
#
# 	6.957 % complete
#
#
# 	6.971 % complete
#
#
# 	6.986 % complete
#
#
# 	7.000 % complete
#
#
# 	7.014 % complete
#
#
# 	7.029 % complete
#
#
# 	7.043 % complete
#
#
# 	7.058 % complete
#
#
# 	7.072 % complete
#
#
# 	7.087 % complete
#
#
# 	7.101 % complete
#
#
# 	7.116 % complete
#
#
# 	7.130 % complete
#
#
# 	7.145 % complete
#
#
# 	7.159 % complete
#
#
# 	7.174 % complete
#
#
# 	7.188 % complete
#
#
# 	7.203 % complete
#
#
# 	7.217 % complete
#
#
# 	7.232 % complete
#
#
# 	7.246 % complete
#
#
# 	7.261 % complete
#
#
# 	7.275 % complete
#
#
# 	7.290 % complete
#
#
# 	7.304 % complete
#
#
# 	7.319 % complete
#
#
# 	7.333 % complete
#
#
# 	7.348 % complete
#
#
# 	7.362 % complete
#
#
# 	7.377 % complete
#
#
# 	7.391 % complete
#
#
# 	7.406 % complete
#
#
# 	7.420 % complete
#
#
# 	7.435 % complete
#
#
# 	7.449 % complete
#
#
# 	7.464 % complete
#
#
# 	7.478 % complete
#
#
# 	7.493 % complete
#
#
# 	7.507 % complete
#
#
# 	7.522 % complete
#
#
# 	7.536 % complete
#
#
# 	7.551 % complete
#
#
# 	7.565 % complete
#
#
# 	7.580 % complete
#
#
# 	7.594 % complete
#
#
# 	7.609 % complete
#
#
# 	7.623 % complete
#
#
# 	7.638 % complete
#
#
# 	7.652 % complete
#
#
# 	7.667 % complete
#
#
# 	7.681 % complete
#
#
# 	7.696 % complete
#
#
# 	7.710 % complete
#
#
# 	7.725 % complete
#
#
# 	7.739 % complete
#
#
# 	7.754 % complete
#
#
# 	7.768 % complete
#
#
# 	7.783 % complete
#
#
# 	7.797 % complete
#
#
# 	7.812 % complete
#
#
# 	7.826 % complete
#
#
# 	7.841 % complete
#
#
# 	7.855 % complete
#
#
# 	7.870 % complete
#
#
# 	7.884 % complete
#
#
# 	7.899 % complete
#
#
# 	7.913 % complete
#
#
# 	7.928 % complete
#
#
# 	7.942 % complete
#
#
# 	7.957 % complete
#
#
# 	7.971 % complete
#
#
# 	7.986 % complete
#
#
# 	8.000 % complete
#
#
# 	8.014 % complete
#
#
# 	8.029 % complete
#
#
# 	8.043 % complete
#
#
# 	8.058 % complete
#
#
# 	8.072 % complete
#
#
# 	8.087 % complete
#
#
# 	8.101 % complete
#
#
# 	8.116 % complete
#
#
# 	8.130 % complete
#
#
# 	8.145 % complete
#
#
# 	8.159 % complete
#
#
# 	8.174 % complete
#
#
# 	8.188 % complete
#
#
# 	8.203 % complete
#
#
# 	8.217 % complete
#
#
# 	8.232 % complete
#
#
# 	8.246 % complete
#
#
# 	8.261 % complete
#
#
# 	8.275 % complete
#
#
# 	8.290 % complete
#
#
# 	8.304 % complete
#
#
# 	8.319 % complete
#
#
# 	8.333 % complete
#
#
# 	8.348 % complete
#
#
# 	8.362 % complete
#
#
# 	8.377 % complete
#
#
# 	8.391 % complete
#
#
# 	8.406 % complete
#
#
# 	8.420 % complete
#
#
# 	8.435 % complete
#
#
# 	8.449 % complete
#
#
# 	8.464 % complete
#
#
# 	8.478 % complete
#
#
# 	8.493 % complete
#
#
# 	8.507 % complete
#
#
# 	8.522 % complete
#
#
# 	8.536 % complete
#
#
# 	8.551 % complete
#
#
# 	8.565 % complete
#
#
# 	8.580 % complete
#
#
# 	8.594 % complete
#
#
# 	8.609 % complete
#
#
# 	8.623 % complete
#
#
# 	8.638 % complete
#
#
# 	8.652 % complete
#
#
# 	8.667 % complete
#
#
# 	8.681 % complete
#
#
# 	8.696 % complete
#
#
# 	8.710 % complete
#
#
# 	8.725 % complete
#
#
# 	8.739 % complete
#
#
# 	8.754 % complete
#
#
# 	8.768 % complete
#
#
# 	8.783 % complete
#
#
# 	8.797 % complete
#
#
# 	8.812 % complete
#
#
# 	8.826 % complete
#
#
# 	8.841 % complete
#
#
# 	8.855 % complete
#
#
# 	8.870 % complete
#
#
# 	8.884 % complete
#
#
# 	8.899 % complete
#
#
# 	8.913 % complete
#
#
# 	8.928 % complete
#
#
# 	8.942 % complete
#
#
# 	8.957 % complete
#
#
# 	8.971 % complete
#
#
# 	8.986 % complete
#
#
# 	9.000 % complete
#
#
# 	9.014 % complete
#
#
# 	9.029 % complete
#
#
# 	9.043 % complete
#
#
# 	9.058 % complete
#
#
# 	9.072 % complete
#
#
# 	9.087 % complete
#
#
# 	9.101 % complete
#
#
# 	9.116 % complete
#
#
# 	9.130 % complete
#
#
# 	9.145 % complete
#
#
# 	9.159 % complete
#
#
# 	9.174 % complete
#
#
# 	9.188 % complete
#
#
# 	9.203 % complete
#
#
# 	9.217 % complete
#
#
# 	9.232 % complete
#
#
# 	9.246 % complete
#
#
# 	9.261 % complete
#
#
# 	9.275 % complete
#
#
# 	9.290 % complete
#
#
# 	9.304 % complete
#
#
# 	9.319 % complete
#
#
# 	9.333 % complete
#
#
# 	9.348 % complete
#
#
# 	9.362 % complete
#
#
# 	9.377 % complete
#
#
# 	9.391 % complete
#
#
# 	9.406 % complete
#
#
# 	9.420 % complete
#
#
# 	9.435 % complete
#
#
# 	9.449 % complete
#
#
# 	9.464 % complete
#
#
# 	9.478 % complete
#
#
# 	9.493 % complete
#
#
# 	9.507 % complete
#
#
# 	9.522 % complete
#
#
# 	9.536 % complete
#
#
# 	9.551 % complete
#
#
# 	9.565 % complete
#
#
# 	9.580 % complete
#
#
# 	9.594 % complete
#
#
# 	9.609 % complete
#
#
# 	9.623 % complete
#
#
# 	9.638 % complete
#
#
# 	9.652 % complete
#
#
# 	9.667 % complete
#
#
# 	9.681 % complete
#
#
# 	9.696 % complete
#
#
# 	9.710 % complete
#
#
# 	9.725 % complete
#
#
# 	9.739 % complete
#
#
# 	9.754 % complete
#
#
# 	9.768 % complete
#
#
# 	9.783 % complete
#
#
# 	9.797 % complete
#
#
# 	9.812 % complete
#
#
# 	9.826 % complete
#
#
# 	9.841 % complete
#
#
# 	9.855 % complete
#
#
# 	9.870 % complete
#
#
# 	9.884 % complete
#
#
# 	9.899 % complete
#
#
# 	9.913 % complete
#
#
# 	9.928 % complete
#
#
# 	9.942 % complete
#
#
# 	9.957 % complete
#
#
# 	9.971 % complete
#
#
# 	9.986 % complete
#
#
# 	10.000 % complete
#
#
# 	10.014 % complete
#
#
# 	10.029 % complete
#
#
# 	10.043 % complete
#
#
# 	10.058 % complete
#
#
# 	10.072 % complete
#
#
# 	10.087 % complete
#
#
# 	10.101 % complete
#
#
# 	10.116 % complete
#
#
# 	10.130 % complete
#
#
# 	10.145 % complete
#
#
# 	10.159 % complete
#
#
# 	10.174 % complete
#
#
# 	10.188 % complete
#
#
# 	10.203 % complete
#
#
# 	10.217 % complete
#
#
# 	10.232 % complete
#
#
# 	10.246 % complete
#
#
# 	10.261 % complete
#
#
# 	10.275 % complete
#
#
# 	10.290 % complete
#
#
# 	10.304 % complete
#
#
# 	10.319 % complete
#
#
# 	10.333 % complete
#
#
# 	10.348 % complete
#
#
# 	10.362 % complete
#
#
# 	10.377 % complete
#
#
# 	10.391 % complete
#
#
# 	10.406 % complete
#
#
# 	10.420 % complete
#
#
# 	10.435 % complete
#
#
# 	10.449 % complete
#
#
# 	10.464 % complete
#
#
# 	10.478 % complete
#
#
# 	10.493 % complete
#
#
# 	10.507 % complete
#
#
# 	10.522 % complete
#
#
# 	10.536 % complete
#
#
# 	10.551 % complete
#
#
# 	10.565 % complete
#
#
# 	10.580 % complete
#
#
# 	10.594 % complete
#
#
# 	10.609 % complete
#
#
# 	10.623 % complete
#
#
# 	10.638 % complete
#
#
# 	10.652 % complete
#
#
# 	10.667 % complete
#
#
# 	10.681 % complete
#
#
# 	10.696 % complete
#
#
# 	10.710 % complete
#
#
# 	10.725 % complete
#
#
# 	10.739 % complete
#
#
# 	10.754 % complete
#
#
# 	10.768 % complete
#
#
# 	10.783 % complete
#
#
# 	10.797 % complete
#
#
# 	10.812 % complete
#
#
# 	10.826 % complete
#
#
# 	10.841 % complete
#
#
# 	10.855 % complete
#
#
# 	10.870 % complete
#
#
# 	10.884 % complete
#
#
# 	10.899 % complete
#
#
# 	10.913 % complete
#
#
# 	10.928 % complete
#
#
# 	10.942 % complete
#
#
# 	10.957 % complete
#
#
# 	10.971 % complete
#
#
# 	10.986 % complete
#
#
# 	11.000 % complete
#
#
# 	11.014 % complete
#
#
# 	11.029 % complete
#
#
# 	11.043 % complete
#
#
# 	11.058 % complete
#
#
# 	11.072 % complete
#
#
# 	11.087 % complete
#
#
# 	11.101 % complete
#
#
# 	11.116 % complete
#
#
# 	11.130 % complete
#
#
# 	11.145 % complete
#
#
# 	11.159 % complete
#
#
# 	11.174 % complete
#
#
# 	11.188 % complete
#
#
# 	11.203 % complete
#
#
# 	11.217 % complete
#
#
# 	11.232 % complete
#
#
# 	11.246 % complete
#
#
# 	11.261 % complete
#
#
# 	11.275 % complete
#
#
# 	11.290 % complete
#
#
# 	11.304 % complete
#
#
# 	11.319 % complete
#
#
# 	11.333 % complete
#
#
# 	11.348 % complete
#
#
# 	11.362 % complete
#
#
# 	11.377 % complete
#
#
# 	11.391 % complete
#
#
# 	11.406 % complete
#
#
# 	11.420 % complete
#
#
# 	11.435 % complete
#
#
# 	11.449 % complete
#
#
# 	11.464 % complete
#
#
# 	11.478 % complete
#
#
# 	11.493 % complete
#
#
# 	11.507 % complete
#
#
# 	11.522 % complete
#
#
# 	11.536 % complete
#
#
# 	11.551 % complete
#
#
# 	11.565 % complete
#
#
# 	11.580 % complete
#
#
# 	11.594 % complete
#
#
# 	11.609 % complete
#
#
# 	11.623 % complete
#
#
# 	11.638 % complete
#
#
# 	11.652 % complete
#
#
# 	11.667 % complete
#
#
# 	11.681 % complete
#
#
# 	11.696 % complete
#
#
# 	11.710 % complete
#
#
# 	11.725 % complete
#
#
# 	11.739 % complete
#
#
# 	11.754 % complete
#
#
# 	11.768 % complete
#
#
# 	11.783 % complete
#
#
# 	11.797 % complete
# 	11.812 % complete
#
#
# 	11.826 % complete
#
#
# 	11.841 % complete
#
#
# 	11.855 % complete
#
#
# 	11.870 % complete
#
#
# 	11.884 % complete
#
#
# 	11.899 % complete
#
#
# 	11.913 % complete
#
#
# 	11.928 % complete
#
#
# 	11.942 % complete
#
#
# 	11.957 % complete
#
#
# 	11.971 % complete
#
#
# 	11.986 % complete
#
#
# 	12.000 % complete
#
#
# 	12.014 % complete
#
#
# 	12.029 % complete
#
#
# 	12.043 % complete
#
#
# 	12.058 % complete
#
#
# 	12.072 % complete
#
#
# 	12.087 % complete
#
#
# 	12.101 % complete
#
#
# 	12.116 % complete
#
#
# 	12.130 % complete
#
#
# 	12.145 % complete
#
#
# 	12.159 % complete
#
#
# 	12.174 % complete
#
#
# 	12.188 % complete
#
#
# 	12.203 % complete
#
#
# 	12.217 % complete
#
#
# 	12.232 % complete
#
#
# 	12.246 % complete
#
#
# 	12.261 % complete
#
#
# 	12.275 % complete
#
#
# 	12.290 % complete
#
#
# 	12.304 % complete
#
#
# 	12.319 % complete
#
#
# 	12.333 % complete
#
#
# 	12.348 % complete
#
#
# 	12.362 % complete
#
#
# 	12.377 % complete
#
#
# 	12.391 % complete
#
#
# 	12.406 % complete
#
#
# 	12.420 % complete
#
#
# 	12.435 % complete
#
#
# 	12.449 % complete
#
#
# 	12.464 % complete
#
#
# 	12.478 % complete
#
#
# 	12.493 % complete
#
#
# 	12.507 % complete
#
#
# 	12.522 % complete
#
#
# 	12.536 % complete
#
#
# 	12.551 % complete
#
#
# 	12.565 % complete
#
#
# 	12.580 % complete
#
#
# 	12.594 % complete
#
#
# 	12.609 % complete
#
#
# 	12.623 % complete
#
#
# 	12.638 % complete
#
#
# 	12.652 % complete
#
#
# 	12.667 % complete
#
#
# 	12.681 % complete
#
#
# 	12.696 % complete
#
#
# 	12.710 % complete
#
#
# 	12.725 % complete
#
#
# 	12.739 % complete
#
#
# 	12.754 % complete
#
#
# 	12.768 % complete
#
#
# 	12.783 % complete
#
#
# 	12.797 % complete
#
#
# 	12.812 % complete
#
#
# 	12.826 % complete
#
#
# 	12.841 % complete
#
#
# 	12.855 % complete
#
#
# 	12.870 % complete
#
#
# 	12.884 % complete
#
#
# 	12.899 % complete
#
#
# 	12.913 % complete
#
#
# 	12.928 % complete
#
#
# 	12.942 % complete
#
#
# 	12.957 % complete
#
#
# 	12.971 % complete
#
#
# 	12.986 % complete
#
#
# 	13.000 % complete
#
#
# 	13.014 % complete
#
#
# 	13.029 % complete
#
#
# 	13.043 % complete
#
#
# 	13.058 % complete
#
#
# 	13.072 % complete
#
#
# 	13.087 % complete
#
#
# 	13.101 % complete
#
#
# 	13.116 % complete
#
#
# 	13.130 % complete
#
#
# 	13.145 % complete
#
#
# 	13.159 % complete
#
#
# 	13.174 % complete
#
#
# 	13.188 % complete
#
#
# 	13.203 % complete
#
#
# 	13.217 % complete
#
#
# 	13.232 % complete
#
#
# 	13.246 % complete
#
#
# 	13.261 % complete
#
#
# 	13.275 % complete
#
#
# 	13.290 % complete
#
#
# 	13.304 % complete
#
#
# 	13.319 % complete
#
#
# 	13.333 % complete
#
#
# 	13.348 % complete
#
#
# 	13.362 % complete
#
#
# 	13.377 % complete
#
#
# 	13.391 % complete
#
#
# 	13.406 % complete
#
#
# 	13.420 % complete
#
#
# 	13.435 % complete
#
#
# 	13.449 % complete
#
#
# 	13.464 % complete
#
#
# 	13.478 % complete
#
#
# 	13.493 % complete
#
#
# 	13.507 % complete
#
#
# 	13.522 % complete
#
#
# 	13.536 % complete
#
#
# 	13.551 % complete
#
#
# 	13.565 % complete
#
#
# 	13.580 % complete
#
#
# 	13.594 % complete
#
#
# 	13.609 % complete
#
#
# 	13.623 % complete
#
#
# 	13.638 % complete
#
#
# 	13.652 % complete
#
#
# 	13.667 % complete
#
#
# 	13.681 % complete
#
#
# 	13.696 % complete
#
#
# 	13.710 % complete
#
#
# 	13.725 % complete
#
#
# 	13.739 % complete
#
#
# 	13.754 % complete
#
#
# 	13.768 % complete
#
#
# 	13.783 % complete
#
#
# 	13.797 % complete
#
#
# 	13.812 % complete
#
#
# 	13.826 % complete
#
#
# 	13.841 % complete
#
#
# 	13.855 % complete
#
#
# 	13.870 % complete
#
#
# 	13.884 % complete
#
#
# 	13.899 % complete
#
#
# 	13.913 % complete
#
#
# 	13.928 % complete
#
#
# 	13.942 % complete
#
#
# 	13.957 % complete
#
#
# 	13.971 % complete
#
#
# 	13.986 % complete
#
#
# 	14.000 % complete
#
#
# 	14.014 % complete
#
#
# 	14.029 % complete
#
#
# 	14.043 % complete
#
#
# 	14.058 % complete
#
#
# 	14.072 % complete
#
#
# 	14.087 % complete
#
#
# 	14.101 % complete
#
#
# 	14.116 % complete
#
#
# 	14.130 % complete
#
#
# 	14.145 % complete
#
#
# 	14.159 % complete
#
#
# 	14.174 % complete
#
#
# 	14.188 % complete
#
#
# 	14.203 % complete
#
#
# 	14.217 % complete
#
#
# 	14.232 % complete
#
#
# 	14.246 % complete
#
#
# 	14.261 % complete
#
#
# 	14.275 % complete
#
#
# 	14.290 % complete
#
#
# 	14.304 % complete
#
#
# 	14.319 % complete
#
#
# 	14.333 % complete
#
#
# 	14.348 % complete
#
#
# 	14.362 % complete
#
#
# 	14.377 % complete
#
#
# 	14.391 % complete
#
#
# 	14.406 % complete
#
#
# 	14.420 % complete
#
#
# 	14.435 % complete
#
#
# 	14.449 % complete
#
#
# 	14.464 % complete
#
#
# 	14.478 % complete
#
#
# 	14.493 % complete
#
#
# 	14.507 % complete
#
#
# 	14.522 % complete
#
#
# 	14.536 % complete
#
#
# 	14.551 % complete
#
#
# 	14.565 % complete
#
#
# 	14.580 % complete
#
#
# 	14.594 % complete
#
#
# 	14.609 % complete
#
#
# 	14.623 % complete
#
#
# 	14.638 % complete
#
#
# 	14.652 % complete
#
#
# 	14.667 % complete
#
#
# 	14.681 % complete
#
#
# 	14.696 % complete
#
#
# 	14.710 % complete
#
#
# 	14.725 % complete
#
#
# 	14.739 % complete
#
#
# 	14.754 % complete
#
#
# 	14.768 % complete
#
#
# 	14.783 % complete
#
#
# 	14.797 % complete
#
#
# 	14.812 % complete
#
#
# 	14.826 % complete
#
#
# 	14.841 % complete
#
#
# 	14.855 % complete
#
#
# 	14.870 % complete
#
#
# 	14.884 % complete
#
#
# 	14.899 % complete
#
#
# 	14.913 % complete
#
#
# 	14.928 % complete
#
#
# 	14.942 % complete
#
#
# 	14.957 % complete
#
#
# 	14.971 % complete
#
#
# 	14.986 % complete
#
#
# 	15.000 % complete
#
#
# 	15.014 % complete
#
#
# 	15.029 % complete
#
#
# 	15.043 % complete
#
#
# 	15.058 % complete
#
#
# 	15.072 % complete
#
#
# 	15.087 % complete
#
#
# 	15.101 % complete
#
#
# 	15.116 % complete
#
#
# 	15.130 % complete
#
#
# 	15.145 % complete
#
#
# 	15.159 % complete
#
#
# 	15.174 % complete
#
#
# 	15.188 % complete
#
#
# 	15.203 % complete
#
#
# 	15.217 % complete
#
#
# 	15.232 % complete
#
#
# 	15.246 % complete
#
#
# 	15.261 % complete
#
#
# 	15.275 % complete
#
#
# 	15.290 % complete
#
#
# 	15.304 % complete
#
#
# 	15.319 % complete
#
#
# 	15.333 % complete
#
#
# 	15.348 % complete
#
#
# 	15.362 % complete
#
#
# 	15.377 % complete
#
#
# 	15.391 % complete
#
#
# 	15.406 % complete
#
#
# 	15.420 % complete
#
#
# 	15.435 % complete
#
#
# 	15.449 % complete
#
#
# 	15.464 % complete
#
#
# 	15.478 % complete
#
#
# 	15.493 % complete
#
#
# 	15.507 % complete
#
#
# 	15.522 % complete
#
#
# 	15.536 % complete
#
#
# 	15.551 % complete
#
#
# 	15.565 % complete
#
#
# 	15.580 % complete
#
#
# 	15.594 % complete
#
#
# 	15.609 % complete
#
#
# 	15.623 % complete
#
#
# 	15.638 % complete
#
#
# 	15.652 % complete
#
#
# 	15.667 % complete
#
#
# 	15.681 % complete
#
#
# 	15.696 % complete
#
#
# 	15.710 % complete
#
#
# 	15.725 % complete
#
#
# 	15.739 % complete
#
#
# 	15.754 % complete
#
#
# 	15.768 % complete
#
#
# 	15.783 % complete
#
#
# 	15.797 % complete
#
#
# 	15.812 % complete
#
#
# 	15.826 % complete
#
#
# 	15.841 % complete
#
#
# 	15.855 % complete
#
#
# 	15.870 % complete
#
#
# 	15.884 % complete
#
#
# 	15.899 % complete
#
#
# 	15.913 % complete
#
#
# 	15.928 % complete
#
#
# 	15.942 % complete
#
#
# 	15.957 % complete
#
#
# 	15.971 % complete
#
#
# 	15.986 % complete
#
#
# 	16.000 % complete
#
#
# 	16.014 % complete
#
#
# 	16.029 % complete
#
#
# 	16.043 % complete
#
#
# 	16.058 % complete
#
#
# 	16.072 % complete
#
#
# 	16.087 % complete
#
#
# 	16.101 % complete
#
#
# 	16.116 % complete
#
#
# 	16.130 % complete
#
#
# 	16.145 % complete
#
#
# 	16.159 % complete
#
#
# 	16.174 % complete
#
#
# 	16.188 % complete
#
#
# 	16.203 % complete
#
#
# 	16.217 % complete
#
#
# 	16.232 % complete
#
#
# 	16.246 % complete
#
#
# 	16.261 % complete
#
#
# 	16.275 % complete
#
#
# 	16.290 % complete
#
#
# 	16.304 % complete
#
#
# 	16.319 % complete
#
#
# 	16.333 % complete
#
#
# 	16.348 % complete
#
#
# 	16.362 % complete
#
#
# 	16.377 % complete
#
#
# 	16.391 % complete
#
#
# 	16.406 % complete
#
#
# 	16.420 % complete
#
#
# 	16.435 % complete
#
#
# 	16.449 % complete
#
#
# 	16.464 % complete
#
#
# 	16.478 % complete
#
#
# 	16.493 % complete
#
#
# 	16.507 % complete
#
#
# 	16.522 % complete
#
#
# 	16.536 % complete
#
#
# 	16.551 % complete
#
#
# 	16.565 % complete
#
#
# 	16.580 % complete
#
#
# 	16.594 % complete
#
#
# 	16.609 % complete
#
#
# 	16.623 % complete
#
#
# 	16.638 % complete
#
#
# 	16.652 % complete
#
#
# 	16.667 % complete
#
#
# 	16.681 % complete
#
#
# 	16.696 % complete
#
#
# 	16.710 % complete
#
#
# 	16.725 % complete
#
#
# 	16.739 % complete
#
#
# 	16.754 % complete
#
#
# 	16.768 % complete
#
#
# 	16.783 % complete
#
#
# 	16.797 % complete
#
#
# 	16.812 % complete
#
#
# 	16.826 % complete
#
#
# 	16.841 % complete
#
#
# 	16.855 % complete
#
#
# 	16.870 % complete
#
#
# 	16.884 % complete
#
#
# 	16.899 % complete
#
#
# 	16.913 % complete
#
#
# 	16.928 % complete
#
#
# 	16.942 % complete
#
#
# 	16.957 % complete
#
#
# 	16.971 % complete
#
#
# 	16.986 % complete
#
#
# 	17.000 % complete
#
#
# 	17.014 % complete
#
#
# 	17.029 % complete
#
#
# 	17.043 % complete
#
#
# 	17.058 % complete
#
#
# 	17.072 % complete
#
#
# 	17.087 % complete
#
#
# 	17.101 % complete
#
#
# 	17.116 % complete
#
#
# 	17.130 % complete
#
#
# 	17.145 % complete
#
#
# 	17.159 % complete
#
#
# 	17.174 % complete
#
#
# 	17.188 % complete
#
#
# 	17.203 % complete
#
#
# 	17.217 % complete
#
#
# 	17.232 % complete
#
#
# 	17.246 % complete
#
#
# 	17.261 % complete
#
#
# 	17.275 % complete
#
#
# 	17.290 % complete
#
#
# 	17.304 % complete
#
#
# 	17.319 % complete
#
#
# 	17.333 % complete
#
#
# 	17.348 % complete
#
#
# 	17.362 % complete
#
#
# 	17.377 % complete
#
#
# 	17.391 % complete
#
#
# 	17.406 % complete
#
#
# 	17.420 % complete
#
#
# 	17.435 % complete
#
#
# 	17.449 % complete
#
#
# 	17.464 % complete
# 	17.478 % complete
#
#
# 	17.493 % complete
#
#
# 	17.507 % complete
#
#
# 	17.522 % complete
#
#
# 	17.536 % complete
#
#
# 	17.551 % complete
#
#
# 	17.565 % complete
#
#
# 	17.580 % complete
#
#
# 	17.594 % complete
#
#
# 	17.609 % complete
#
#
# 	17.623 % complete
#
#
# 	17.638 % complete
#
#
# 	17.652 % complete
#
#
# 	17.667 % complete
#
#
# 	17.681 % complete
#
#
# 	17.696 % complete
#
#
# 	17.710 % complete
#
#
# 	17.725 % complete
#
#
# 	17.739 % complete
#
#
# 	17.754 % complete
#
#
# 	17.768 % complete
#
#
# 	17.783 % complete
#
#
# 	17.797 % complete
#
#
# 	17.812 % complete
#
#
# 	17.826 % complete
#
#
# 	17.841 % complete
#
#
# 	17.855 % complete
#
#
# 	17.870 % complete
#
#
# 	17.884 % complete
#
#
# 	17.899 % complete
#
#
# 	17.913 % complete
#
#
# 	17.928 % complete
#
#
# 	17.942 % complete
#
#
# 	17.957 % complete
#
#
# 	17.971 % complete
#
#
# 	17.986 % complete
#
#
# 	18.000 % complete
#
#
# 	18.014 % complete
#
#
# 	18.029 % complete
#
#
# 	18.043 % complete
#
#
# 	18.058 % complete
#
#
# 	18.072 % complete
#
#
# 	18.087 % complete
#
#
# 	18.101 % complete
#
#
# 	18.116 % complete
#
#
# 	18.130 % complete
#
#
# 	18.145 % complete
#
#
# 	18.159 % complete
#
#
# 	18.174 % complete
#
#
# 	18.188 % complete
#
#
# 	18.203 % complete
#
#
# 	18.217 % complete
#
#
# 	18.232 % complete
#
#
# 	18.246 % complete
#
#
# 	18.261 % complete
#
#
# 	18.275 % complete
#
#
# 	18.290 % complete
#
#
# 	18.304 % complete
#
#
# 	18.319 % complete
#
#
# 	18.333 % complete
#
#
# 	18.348 % complete
#
#
# 	18.362 % complete
#
#
# 	18.377 % complete
#
#
# 	18.391 % complete
#
#
# 	18.406 % complete
#
#
# 	18.420 % complete
#
#
# 	18.435 % complete
#
#
# 	18.449 % complete
#
#
# 	18.464 % complete
#
#
# 	18.478 % complete
#
#
# 	18.493 % complete
#
#
# 	18.507 % complete
#
#
# 	18.522 % complete
#
#
# 	18.536 % complete
#
#
# 	18.551 % complete
#
#
# 	18.565 % complete
#
#
# 	18.580 % complete
#
#
# 	18.594 % complete
#
#
# 	18.609 % complete
#
#
# 	18.623 % complete
#
#
# 	18.638 % complete
#
#
# 	18.652 % complete
#
#
# 	18.667 % complete
#
#
# 	18.681 % complete
#
#
# 	18.696 % complete
#
#
# 	18.710 % complete
#
#
# 	18.725 % complete
#
#
# 	18.739 % complete
#
#
# 	18.754 % complete
#
#
# 	18.768 % complete
#
#
# 	18.783 % complete
#
#
# 	18.797 % complete
#
#
# 	18.812 % complete
#
#
# 	18.826 % complete
#
#
# 	18.841 % complete
#
#
# 	18.855 % complete
#
#
# 	18.870 % complete
#
#
# 	18.884 % complete
#
#
# 	18.899 % complete
#
#
# 	18.913 % complete
#
#
# 	18.928 % complete
#
#
# 	18.942 % complete
#
#
# 	18.957 % complete
#
#
# 	18.971 % complete
#
#
# 	18.986 % complete
#
#
# 	19.000 % complete
#
#
# 	19.014 % complete
#
#
# 	19.029 % complete
#
#
# 	19.043 % complete
#
#
# 	19.058 % complete
#
#
# 	19.072 % complete
#
#
# 	19.087 % complete
#
#
# 	19.101 % complete
#
#
# 	19.116 % complete
#
#
# 	19.130 % complete
#
#
# 	19.145 % complete
#
#
# 	19.159 % complete
#
#
# 	19.174 % complete
#
#
# 	19.188 % complete
#
#
# 	19.203 % complete
#
#
# 	19.217 % complete
#
#
# 	19.232 % complete
#
#
# 	19.246 % complete
#
#
# 	19.261 % complete
#
#
# 	19.275 % complete
#
#
# 	19.290 % complete
#
#
# 	19.304 % complete
#
#
# 	19.319 % complete
#
#
# 	19.333 % complete
#
#
# 	19.348 % complete
#
#
# 	19.362 % complete
#
#
# 	19.377 % complete
#
#
# 	19.391 % complete
#
#
# 	19.406 % complete
#
#
# 	19.420 % complete
#
#
# 	19.435 % complete
#
#
# 	19.449 % complete
#
#
# 	19.464 % complete
#
#
# 	19.478 % complete
#
#
# 	19.493 % complete
#
#
# 	19.507 % complete
#
#
# 	19.522 % complete
#
#
# 	19.536 % complete
#
#
# 	19.551 % complete
#
#
# 	19.565 % complete
#
#
# 	19.580 % complete
#
#
# 	19.594 % complete
#
#
# 	19.609 % complete
#
#
# 	19.623 % complete
#
#
# 	19.638 % complete
#
#
# 	19.652 % complete
#
#
# 	19.667 % complete
#
#
# 	19.681 % complete
#
#
# 	19.696 % complete
#
#
# 	19.710 % complete
#
#
# 	19.725 % complete
#
#
# 	19.739 % complete
#
#
# 	19.754 % complete
#
#
# 	19.768 % complete
#
#
# 	19.783 % complete
#
#
# 	19.797 % complete
#
#
# 	19.812 % complete
#
#
# 	19.826 % complete
#
#
# 	19.841 % complete
#
#
# 	19.855 % complete
#
#
# 	19.870 % complete
#
#
# 	19.884 % complete
#
#
# 	19.899 % complete
#
#
# 	19.913 % complete
#
#
# 	19.928 % complete
#
#
# 	19.942 % complete
#
#
# 	19.957 % complete
#
#
# 	19.971 % complete
#
#
# 	19.986 % complete
#
#
# 	20.000 % complete
#
#
# 	20.014 % complete
#
#
# 	20.029 % complete
#
#
# 	20.043 % complete
#
#
# 	20.058 % complete
#
#
# 	20.072 % complete
#
#
# 	20.087 % complete
#
#
# 	20.101 % complete
#
#
# 	20.116 % complete
#
#
# 	20.130 % complete
#
#
# 	20.145 % complete
#
#
# 	20.159 % complete
#
#
# 	20.174 % complete
#
#
# 	20.188 % complete
#
#
# 	20.203 % complete
#
#
# 	20.217 % complete
#
#
# 	20.232 % complete
#
#
# 	20.246 % complete
#
#
# 	20.261 % complete
#
#
# 	20.275 % complete
#
#
# 	20.290 % complete
#
#
# 	20.304 % complete
#
#
# 	20.319 % complete
#
#
# 	20.333 % complete
#
#
# 	20.348 % complete
#
#
# 	20.362 % complete
#
#
# 	20.377 % complete
#
#
# 	20.391 % complete
#
#
# 	20.406 % complete
#
#
# 	20.420 % complete
#
#
# 	20.435 % complete
#
#
# 	20.449 % complete
#
#
# 	20.464 % complete
#
#
# 	20.478 % complete
#
#
# 	20.493 % complete
#
#
# 	20.507 % complete
#
#
# 	20.522 % complete
#
#
# 	20.536 % complete
#
#
# 	20.551 % complete
#
#
# 	20.565 % complete
#
#
# 	20.580 % complete
#
#
# 	20.594 % complete
#
#
# 	20.609 % complete
#
#
# 	20.623 % complete
#
#
# 	20.638 % complete
#
#
# 	20.652 % complete
#
#
# 	20.667 % complete
#
#
# 	20.681 % complete
#
#
# 	20.696 % complete
#
#
# 	20.710 % complete
#
#
# 	20.725 % complete
#
#
# 	20.739 % complete
#
#
# 	20.754 % complete
#
#
# 	20.768 % complete
#
#
# 	20.783 % complete
#
#
# 	20.797 % complete
#
#
# 	20.812 % complete
#
#
# 	20.826 % complete
#
#
# 	20.841 % complete
#
#
# 	20.855 % complete
#
#
# 	20.870 % complete
#
#
# 	20.884 % complete
#
#
# 	20.899 % complete
#
#
# 	20.913 % complete
#
#
# 	20.928 % complete
#
#
# 	20.942 % complete
#
#
# 	20.957 % complete
#
#
# 	20.971 % complete
#
#
# 	20.986 % complete
#
#
# 	21.000 % complete
#
#
# 	21.014 % complete
#
#
# 	21.029 % complete
#
#
# 	21.043 % complete
#
#
# 	21.058 % complete
#
#
# 	21.072 % complete
#
#
# 	21.087 % complete
#
#
# 	21.101 % complete
#
#
# 	21.116 % complete
#
#
# 	21.130 % complete
#
#
# 	21.145 % complete
#
#
# 	21.159 % complete
#
#
# 	21.174 % complete
#
#
# 	21.188 % complete
#
#
# 	21.203 % complete
#
#
# 	21.217 % complete
#
#
# 	21.232 % complete
#
#
# 	21.246 % complete
#
#
# 	21.261 % complete
#
#
# 	21.275 % complete
#
#
# 	21.290 % complete
#
#
# 	21.304 % complete
#
#
# 	21.319 % complete
#
#
# 	21.333 % complete
#
#
# 	21.348 % complete
#
#
# 	21.362 % complete
#
#
# 	21.377 % complete
#
#
# 	21.391 % complete
#
#
# 	21.406 % complete
#
#
# 	21.420 % complete
#
#
# 	21.435 % complete
#
#
# 	21.449 % complete
#
#
# 	21.464 % complete
#
#
# 	21.478 % complete
#
#
# 	21.493 % complete
#
#
# 	21.507 % complete
#
#
# 	21.522 % complete
#
#
# 	21.536 % complete
#
#
# 	21.551 % complete
#
#
# 	21.565 % complete
#
#
# 	21.580 % complete
#
#
# 	21.594 % complete
#
#
# 	21.609 % complete
#
#
# 	21.623 % complete
#
#
# 	21.638 % complete
#
#
# 	21.652 % complete
#
#
# 	21.667 % complete
#
#
# 	21.681 % complete
#
#
# 	21.696 % complete
#
#
# 	21.710 % complete
#
#
# 	21.725 % complete
#
#
# 	21.739 % complete
#
#
# 	21.754 % complete
#
#
# 	21.768 % complete
#
#
# 	21.783 % complete
#
#
# 	21.797 % complete
#
#
# 	21.812 % complete
#
#
# 	21.826 % complete
#
#
# 	21.841 % complete
#
#
# 	21.855 % complete
#
#
# 	21.870 % complete
#
#
# 	21.884 % complete
#
#
# 	21.899 % complete
#
#
# 	21.913 % complete
#
#
# 	21.928 % complete
#
#
# 	21.942 % complete
#
#
# 	21.957 % complete
#
#
# 	21.971 % complete
#
#
# 	21.986 % complete
#
#
# 	22.000 % complete
#
#
# 	22.014 % complete
#
#
# 	22.029 % complete
#
#
# 	22.043 % complete
#
#
# 	22.058 % complete
#
#
# 	22.072 % complete
#
#
# 	22.087 % complete
#
#
# 	22.101 % complete
#
#
# 	22.116 % complete
#
#
# 	22.130 % complete
#
#
# 	22.145 % complete
#
#
# 	22.159 % complete
#
#
# 	22.174 % complete
#
#
# 	22.188 % complete
#
#
# 	22.203 % complete
#
#
# 	22.217 % complete
#
#
# 	22.232 % complete
#
#
# 	22.246 % complete
#
#
# 	22.261 % complete
#
#
# 	22.275 % complete
#
#
# 	22.290 % complete
#
#
# 	22.304 % complete
#
#
# 	22.319 % complete
#
#
# 	22.333 % complete
#
#
# 	22.348 % complete
#
#
# 	22.362 % complete
#
#
# 	22.377 % complete
#
#
# 	22.391 % complete
#
#
# 	22.406 % complete
#
#
# 	22.420 % complete
#
#
# 	22.435 % complete
#
#
# 	22.449 % complete
#
#
# 	22.464 % complete
#
#
# 	22.478 % complete
#
#
# 	22.493 % complete
#
#
# 	22.507 % complete
#
#
# 	22.522 % complete
#
#
# 	22.536 % complete
#
#
# 	22.551 % complete
#
#
# 	22.565 % complete
#
#
# 	22.580 % complete
#
#
# 	22.594 % complete
#
#
# 	22.609 % complete
#
#
# 	22.623 % complete
#
#
# 	22.638 % complete
#
#
# 	22.652 % complete
#
#
# 	22.667 % complete
#
#
# 	22.681 % complete
#
#
# 	22.696 % complete
#
#
# 	22.710 % complete
#
#
# 	22.725 % complete
#
#
# 	22.739 % complete
#
#
# 	22.754 % complete
#
#
# 	22.768 % complete
#
#
# 	22.783 % complete
#
#
# 	22.797 % complete
#
#
# 	22.812 % complete
#
#
# 	22.826 % complete
#
#
# 	22.841 % complete
#
#
# 	22.855 % complete
#
#
# 	22.870 % complete
#
#
# 	22.884 % complete
#
#
# 	22.899 % complete
#
#
# 	22.913 % complete
#
#
# 	22.928 % complete
#
#
# 	22.942 % complete
#
#
# 	22.957 % complete
#
#
# 	22.971 % complete
#
#
# 	22.986 % complete
#
#
# 	23.000 % complete
#
#
# 	23.014 % complete
#
#
# 	23.029 % complete
#
#
# 	23.043 % complete
#
#
# 	23.058 % complete
#
#
# 	23.072 % complete
#
#
# 	23.087 % complete
#
#
# 	23.101 % complete
#
#
# 	23.116 % complete
#
#
# 	23.130 % complete
# 	23.145 % complete
#
#
# 	23.159 % complete
#
#
# 	23.174 % complete
#
#
# 	23.188 % complete
#
#
# 	23.203 % complete
#
#
# 	23.217 % complete
#
#
# 	23.232 % complete
#
#
# 	23.246 % complete
#
#
# 	23.261 % complete
#
#
# 	23.275 % complete
#
#
# 	23.290 % complete
#
#
# 	23.304 % complete
#
#
# 	23.319 % complete
#
#
# 	23.333 % complete
#
#
# 	23.348 % complete
#
#
# 	23.362 % complete
#
#
# 	23.377 % complete
#
#
# 	23.391 % complete
#
#
# 	23.406 % complete
#
#
# 	23.420 % complete
#
#
# 	23.435 % complete
#
#
# 	23.449 % complete
#
#
# 	23.464 % complete
#
#
# 	23.478 % complete
#
#
# 	23.493 % complete
#
#
# 	23.507 % complete
#
#
# 	23.522 % complete
#
#
# 	23.536 % complete
#
#
# 	23.551 % complete
#
#
# 	23.565 % complete
#
#
# 	23.580 % complete
#
#
# 	23.594 % complete
#
#
# 	23.609 % complete
#
#
# 	23.623 % complete
#
#
# 	23.638 % complete
#
#
# 	23.652 % complete
#
#
# 	23.667 % complete
#
#
# 	23.681 % complete
#
#
# 	23.696 % complete
#
#
# 	23.710 % complete
#
#
# 	23.725 % complete
#
#
# 	23.739 % complete
#
#
# 	23.754 % complete
#
#
# 	23.768 % complete
#
#
# 	23.783 % complete
#
#
# 	23.797 % complete
#
#
# 	23.812 % complete
#
#
# 	23.826 % complete
#
#
# 	23.841 % complete
#
#
# 	23.855 % complete
#
#
# 	23.870 % complete
#
#
# 	23.884 % complete
#
#
# 	23.899 % complete
#
#
# 	23.913 % complete
#
#
# 	23.928 % complete
#
#
# 	23.942 % complete
#
#
# 	23.957 % complete
#
#
# 	23.971 % complete
#
#
# 	23.986 % complete
#
#
# 	24.000 % complete
#
#
# 	24.014 % complete
#
#
# 	24.029 % complete
#
#
# 	24.043 % complete
#
#
# 	24.058 % complete
#
#
# 	24.072 % complete
#
#
# 	24.087 % complete
#
#
# 	24.101 % complete
#
#
# 	24.116 % complete
#
#
# 	24.130 % complete
#
#
# 	24.145 % complete
#
#
# 	24.159 % complete
#
#
# 	24.174 % complete
#
#
# 	24.188 % complete
#
#
# 	24.203 % complete
#
#
# 	24.217 % complete
#
#
# 	24.232 % complete
#
#
# 	24.246 % complete
#
#
# 	24.261 % complete
#
#
# 	24.275 % complete
#
#
# 	24.290 % complete
#
#
# 	24.304 % complete
#
#
# 	24.319 % complete
#
#
# 	24.333 % complete
#
#
# 	24.348 % complete
#
#
# 	24.362 % complete
#
#
# 	24.377 % complete
#
#
# 	24.391 % complete
#
#
# 	24.406 % complete
#
#
# 	24.420 % complete
#
#
# 	24.435 % complete
#
#
# 	24.449 % complete
#
#
# 	24.464 % complete
#
#
# 	24.478 % complete
#
#
# 	24.493 % complete
#
#
# 	24.507 % complete
#
#
# 	24.522 % complete
#
#
# 	24.536 % complete
#
#
# 	24.551 % complete
#
#
# 	24.565 % complete
#
#
# 	24.580 % complete
#
#
# 	24.594 % complete
#
#
# 	24.609 % complete
#
#
# 	24.623 % complete
#
#
# 	24.638 % complete
#
#
# 	24.652 % complete
#
#
# 	24.667 % complete
#
#
# 	24.681 % complete
#
#
# 	24.696 % complete
#
#
# 	24.710 % complete
#
#
# 	24.725 % complete
#
#
# 	24.739 % complete
#
#
# 	24.754 % complete
#
#
# 	24.768 % complete
#
#
# 	24.783 % complete
#
#
# 	24.797 % complete
#
#
# 	24.812 % complete
#
#
# 	24.826 % complete
#
#
# 	24.841 % complete
#
#
# 	24.855 % complete
#
#
# 	24.870 % complete
#
#
# 	24.884 % complete
#
#
# 	24.899 % complete
#
#
# 	24.913 % complete
#
#
# 	24.928 % complete
#
#
# 	24.942 % complete
#
#
# 	24.957 % complete
#
#
# 	24.971 % complete
#
#
# 	24.986 % complete
#
#
# 	25.000 % complete
#
#
# 	25.014 % complete
#
#
# 	25.029 % complete
#
#
# 	25.043 % complete
#
#
# 	25.058 % complete
#
#
# 	25.072 % complete
#
#
# 	25.087 % complete
#
#
# 	25.101 % complete
#
#
# 	25.116 % complete
#
#
# 	25.130 % complete
#
#
# 	25.145 % complete
#
#
# 	25.159 % complete
#
#
# 	25.174 % complete
#
#
# 	25.188 % complete
#
#
# 	25.203 % complete
#
#
# 	25.217 % complete
#
#
# 	25.232 % complete
#
#
# 	25.246 % complete
#
#
# 	25.261 % complete
#
#
# 	25.275 % complete
#
#
# 	25.290 % complete
#
#
# 	25.304 % complete
#
#
# 	25.319 % complete
#
#
# 	25.333 % complete
#
#
# 	25.348 % complete
#
#
# 	25.362 % complete
#
#
# 	25.377 % complete
#
#
# 	25.391 % complete
#
#
# 	25.406 % complete
#
#
# 	25.420 % complete
#
#
# 	25.435 % complete
#
#
# 	25.449 % complete
#
#
# 	25.464 % complete
#
#
# 	25.478 % complete
#
#
# 	25.493 % complete
#
#
# 	25.507 % complete
#
#
# 	25.522 % complete
#
#
# 	25.536 % complete
#
#
# 	25.551 % complete
#
#
# 	25.565 % complete
#
#
# 	25.580 % complete
#
#
# 	25.594 % complete
#
#
# 	25.609 % complete
#
#
# 	25.623 % complete
#
#
# 	25.638 % complete
#
#
# 	25.652 % complete
#
#
# 	25.667 % complete
#
#
# 	25.681 % complete
#
#
# 	25.696 % complete
#
#
# 	25.710 % complete
#
#
# 	25.725 % complete
#
#
# 	25.739 % complete
#
#
# 	25.754 % complete
#
#
# 	25.768 % complete
#
#
# 	25.783 % complete
#
#
# 	25.797 % complete
#
#
# 	25.812 % complete
#
#
# 	25.826 % complete
#
#
# 	25.841 % complete
#
#
# 	25.855 % complete
#
#
# 	25.870 % complete
#
#
# 	25.884 % complete
#
#
# 	25.899 % complete
#
#
# 	25.913 % complete
#
#
# 	25.928 % complete
#
#
# 	25.942 % complete
#
#
# 	25.957 % complete
#
#
# 	25.971 % complete
#
#
# 	25.986 % complete
#
#
# 	26.000 % complete
#
#
# 	26.014 % complete
#
#
# 	26.029 % complete
#
#
# 	26.043 % complete
#
#
# 	26.058 % complete
#
#
# 	26.072 % complete
#
#
# 	26.087 % complete
#
#
# 	26.101 % complete
#
#
# 	26.116 % complete
#
#
# 	26.130 % complete
#
#
# 	26.145 % complete
#
#
# 	26.159 % complete
#
#
# 	26.174 % complete
#
#
# 	26.188 % complete
#
#
# 	26.203 % complete
#
#
# 	26.217 % complete
#
#
# 	26.232 % complete
#
#
# 	26.246 % complete
#
#
# 	26.261 % complete
#
#
# 	26.275 % complete
#
#
# 	26.290 % complete
#
#
# 	26.304 % complete
#
#
# 	26.319 % complete
#
#
# 	26.333 % complete
#
#
# 	26.348 % complete
#
#
# 	26.362 % complete
#
#
# 	26.377 % complete
#
#
# 	26.391 % complete
#
#
# 	26.406 % complete
#
#
# 	26.420 % complete
#
#
# 	26.435 % complete
#
#
# 	26.449 % complete
#
#
# 	26.464 % complete
#
#
# 	26.478 % complete
#
#
# 	26.493 % complete
#
#
# 	26.507 % complete
#
#
# 	26.522 % complete
#
#
# 	26.536 % complete
#
#
# 	26.551 % complete
#
#
# 	26.565 % complete
#
#
# 	26.580 % complete
#
#
# 	26.594 % complete
#
#
# 	26.609 % complete
#
#
# 	26.623 % complete
#
#
# 	26.638 % complete
#
#
# 	26.652 % complete
#
#
# 	26.667 % complete
#
#
# 	26.681 % complete
#
#
# 	26.696 % complete
#
#
# 	26.710 % complete
#
#
# 	26.725 % complete
#
#
# 	26.739 % complete
#
#
# 	26.754 % complete
#
#
# 	26.768 % complete
#
#
# 	26.783 % complete
#
#
# 	26.797 % complete
#
#
# 	26.812 % complete
#
#
# 	26.826 % complete
#
#
# 	26.841 % complete
#
#
# 	26.855 % complete
#
#
# 	26.870 % complete
#
#
# 	26.884 % complete
#
#
# 	26.899 % complete
#
#
# 	26.913 % complete
#
#
# 	26.928 % complete
#
#
# 	26.942 % complete
#
#
# 	26.957 % complete
#
#
# 	26.971 % complete
#
#
# 	26.986 % complete
#
#
# 	27.000 % complete
#
#
# 	27.014 % complete
#
#
# 	27.029 % complete
#
#
# 	27.043 % complete
#
#
# 	27.058 % complete
#
#
# 	27.072 % complete
#
#
# 	27.087 % complete
#
#
# 	27.101 % complete
#
#
# 	27.116 % complete
#
#
# 	27.130 % complete
#
#
# 	27.145 % complete
#
#
# 	27.159 % complete
#
#
# 	27.174 % complete
#
#
# 	27.188 % complete
#
#
# 	27.203 % complete
#
#
# 	27.217 % complete
#
#
# 	27.232 % complete
#
#
# 	27.246 % complete
#
#
# 	27.261 % complete
#
#
# 	27.275 % complete
#
#
# 	27.290 % complete
#
#
# 	27.304 % complete
#
#
# 	27.319 % complete
#
#
# 	27.333 % complete
#
#
# 	27.348 % complete
#
#
# 	27.362 % complete
#
#
# 	27.377 % complete
#
#
# 	27.391 % complete
#
#
# 	27.406 % complete
#
#
# 	27.420 % complete
#
#
# 	27.435 % complete
#
#
# 	27.449 % complete
#
#
# 	27.464 % complete
#
#
# 	27.478 % complete
#
#
# 	27.493 % complete
#
#
# 	27.507 % complete
#
#
# 	27.522 % complete
#
#
# 	27.536 % complete
#
#
# 	27.551 % complete
#
#
# 	27.565 % complete
#
#
# 	27.580 % complete
#
#
# 	27.594 % complete
#
#
# 	27.609 % complete
#
#
# 	27.623 % complete
#
#
# 	27.638 % complete
#
#
# 	27.652 % complete
#
#
# 	27.667 % complete
#
#
# 	27.681 % complete
#
#
# 	27.696 % complete
#
#
# 	27.710 % complete
#
#
# 	27.725 % complete
#
#
# 	27.739 % complete
#
#
# 	27.754 % complete
#
#
# 	27.768 % complete
#
#
# 	27.783 % complete
#
#
# 	27.797 % complete
#
#
# 	27.812 % complete
#
#
# 	27.826 % complete
#
#
# 	27.841 % complete
#
#
# 	27.855 % complete
#
#
# 	27.870 % complete
#
#
# 	27.884 % complete
#
#
# 	27.899 % complete
#
#
# 	27.913 % complete
#
#
# 	27.928 % complete
#
#
# 	27.942 % complete
#
#
# 	27.957 % complete
#
#
# 	27.971 % complete
#
#
# 	27.986 % complete
#
#
# 	28.000 % complete
#
#
# 	28.014 % complete
#
#
# 	28.029 % complete
#
#
# 	28.043 % complete
#
#
# 	28.058 % complete
#
#
# 	28.072 % complete
#
#
# 	28.087 % complete
#
#
# 	28.101 % complete
#
#
# 	28.116 % complete
#
#
# 	28.130 % complete
#
#
# 	28.145 % complete
#
#
# 	28.159 % complete
#
#
# 	28.174 % complete
#
#
# 	28.188 % complete
#
#
# 	28.203 % complete
#
#
# 	28.217 % complete
#
#
# 	28.232 % complete
#
#
# 	28.246 % complete
#
#
# 	28.261 % complete
#
#
# 	28.275 % complete
#
#
# 	28.290 % complete
#
#
# 	28.304 % complete
#
#
# 	28.319 % complete
#
#
# 	28.333 % complete
#
#
# 	28.348 % complete
#
#
# 	28.362 % complete
#
#
# 	28.377 % complete
#
#
# 	28.391 % complete
#
#
# 	28.406 % complete
#
#
# 	28.420 % complete
#
#
# 	28.435 % complete
#
#
# 	28.449 % complete
#
#
# 	28.464 % complete
#
#
# 	28.478 % complete
#
#
# 	28.493 % complete
#
#
# 	28.507 % complete
#
#
# 	28.522 % complete
#
#
# 	28.536 % complete
#
#
# 	28.551 % complete
#
#
# 	28.565 % complete
#
#
# 	28.580 % complete
#
#
# 	28.594 % complete
#
#
# 	28.609 % complete
#
#
# 	28.623 % complete
#
#
# 	28.638 % complete
#
#
# 	28.652 % complete
#
#
# 	28.667 % complete
#
#
# 	28.681 % complete
#
#
# 	28.696 % complete
#
#
# 	28.710 % complete
#
#
# 	28.725 % complete
#
#
# 	28.739 % complete
#
#
# 	28.754 % complete
#
#
# 	28.768 % complete
#
#
# 	28.783 % complete
#
#
# 	28.797 % complete
# 	28.812 % complete
#
#
# 	28.826 % complete
#
#
# 	28.841 % complete
#
#
# 	28.855 % complete
#
#
# 	28.870 % complete
#
#
# 	28.884 % complete
#
#
# 	28.899 % complete
#
#
# 	28.913 % complete
#
#
# 	28.928 % complete
#
#
# 	28.942 % complete
#
#
# 	28.957 % complete
#
#
# 	28.971 % complete
#
#
# 	28.986 % complete
#
#
# 	29.000 % complete
#
#
# 	29.014 % complete
#
#
# 	29.029 % complete
#
#
# 	29.043 % complete
#
#
# 	29.058 % complete
#
#
# 	29.072 % complete
#
#
# 	29.087 % complete
#
#
# 	29.101 % complete
#
#
# 	29.116 % complete
#
#
# 	29.130 % complete
#
#
# 	29.145 % complete
#
#
# 	29.159 % complete
#
#
# 	29.174 % complete
#
#
# 	29.188 % complete
#
#
# 	29.203 % complete
#
#
# 	29.217 % complete
#
#
# 	29.232 % complete
#
#
# 	29.246 % complete
#
#
# 	29.261 % complete
#
#
# 	29.275 % complete
#
#
# 	29.290 % complete
#
#
# 	29.304 % complete
#
#
# 	29.319 % complete
#
#
# 	29.333 % complete
#
#
# 	29.348 % complete
#
#
# 	29.362 % complete
#
#
# 	29.377 % complete
#
#
# 	29.391 % complete
#
#
# 	29.406 % complete
#
#
# 	29.420 % complete
#
#
# 	29.435 % complete
#
#
# 	29.449 % complete
#
#
# 	29.464 % complete
#
#
# 	29.478 % complete
#
#
# 	29.493 % complete
#
#
# 	29.507 % complete
#
#
# 	29.522 % complete
#
#
# 	29.536 % complete
#
#
# 	29.551 % complete
#
#
# 	29.565 % complete
#
#
# 	29.580 % complete
#
#
# 	29.594 % complete
#
#
# 	29.609 % complete
#
#
# 	29.623 % complete
#
#
# 	29.638 % complete
#
#
# 	29.652 % complete
#
#
# 	29.667 % complete
#
#
# 	29.681 % complete
#
#
# 	29.696 % complete
#
#
# 	29.710 % complete
#
#
# 	29.725 % complete
#
#
# 	29.739 % complete
#
#
# 	29.754 % complete
#
#
# 	29.768 % complete
#
#
# 	29.783 % complete
#
#
# 	29.797 % complete
#
#
# 	29.812 % complete
#
#
# 	29.826 % complete
#
#
# 	29.841 % complete
#
#
# 	29.855 % complete
#
#
# 	29.870 % complete
#
#
# 	29.884 % complete
#
#
# 	29.899 % complete
#
#
# 	29.913 % complete
#
#
# 	29.928 % complete
#
#
# 	29.942 % complete
#
#
# 	29.957 % complete
#
#
# 	29.971 % complete
#
#
# 	29.986 % complete
#
#
# 	30.000 % complete
#
#
# 	30.014 % complete
#
#
# 	30.029 % complete
#
#
# 	30.043 % complete
#
#
# 	30.058 % complete
#
#
# 	30.072 % complete
#
#
# 	30.087 % complete
#
#
# 	30.101 % complete
#
#
# 	30.116 % complete
#
#
# 	30.130 % complete
#
#
# 	30.145 % complete
#
#
# 	30.159 % complete
#
#
# 	30.174 % complete
#
#
# 	30.188 % complete
#
#
# 	30.203 % complete
#
#
# 	30.217 % complete
#
#
# 	30.232 % complete
#
#
# 	30.246 % complete
#
#
# 	30.261 % complete
#
#
# 	30.275 % complete
#
#
# 	30.290 % complete
#
#
# 	30.304 % complete
#
#
# 	30.319 % complete
#
#
# 	30.333 % complete
#
#
# 	30.348 % complete
#
#
# 	30.362 % complete
#
#
# 	30.377 % complete
#
#
# 	30.391 % complete
#
#
# 	30.406 % complete
#
#
# 	30.420 % complete
#
#
# 	30.435 % complete
#
#
# 	30.449 % complete
#
#
# 	30.464 % complete
#
#
# 	30.478 % complete
#
#
# 	30.493 % complete
#
#
# 	30.507 % complete
#
#
# 	30.522 % complete
#
#
# 	30.536 % complete
#
#
# 	30.551 % complete
#
#
# 	30.565 % complete
#
#
# 	30.580 % complete
#
#
# 	30.594 % complete
#
#
# 	30.609 % complete
#
#
# 	30.623 % complete
#
#
# 	30.638 % complete
#
#
# 	30.652 % complete
#
#
# 	30.667 % complete
#
#
# 	30.681 % complete
#
#
# 	30.696 % complete
#
#
# 	30.710 % complete
#
#
# 	30.725 % complete
#
#
# 	30.739 % complete
#
#
# 	30.754 % complete
#
#
# 	30.768 % complete
#
#
# 	30.783 % complete
#
#
# 	30.797 % complete
#
#
# 	30.812 % complete
#
#
# 	30.826 % complete
#
#
# 	30.841 % complete
#
#
# 	30.855 % complete
#
#
# 	30.870 % complete
#
#
# 	30.884 % complete
#
#
# 	30.899 % complete
#
#
# 	30.913 % complete
#
#
# 	30.928 % complete
#
#
# 	30.942 % complete
#
#
# 	30.957 % complete
#
#
# 	30.971 % complete
#
#
# 	30.986 % complete
#
#
# 	31.000 % complete
#
#
# 	31.014 % complete
#
#
# 	31.029 % complete
#
#
# 	31.043 % complete
#
#
# 	31.058 % complete
#
#
# 	31.072 % complete
#
#
# 	31.087 % complete
#
#
# 	31.101 % complete
#
#
# 	31.116 % complete
#
#
# 	31.130 % complete
#
#
# 	31.145 % complete
#
#
# 	31.159 % complete
#
#
# 	31.174 % complete
#
#
# 	31.188 % complete
#
#
# 	31.203 % complete
#
#
# 	31.217 % complete
#
#
# 	31.232 % complete
#
#
# 	31.246 % complete
#
#
# 	31.261 % complete
#
#
# 	31.275 % complete
#
#
# 	31.290 % complete
#
#
# 	31.304 % complete
#
#
# 	31.319 % complete
#
#
# 	31.333 % complete
#
#
# 	31.348 % complete
#
#
# 	31.362 % complete
#
#
# 	31.377 % complete
#
#
# 	31.391 % complete
#
#
# 	31.406 % complete
#
#
# 	31.420 % complete
#
#
# 	31.435 % complete
#
#
# 	31.449 % complete
#
#
# 	31.464 % complete
#
#
# 	31.478 % complete
#
#
# 	31.493 % complete
#
#
# 	31.507 % complete
#
#
# 	31.522 % complete
#
#
# 	31.536 % complete
#
#
# 	31.551 % complete
#
#
# 	31.565 % complete
#
#
# 	31.580 % complete
#
#
# 	31.594 % complete
#
#
# 	31.609 % complete
#
#
# 	31.623 % complete
#
#
# 	31.638 % complete
#
#
# 	31.652 % complete
#
#
# 	31.667 % complete
#
#
# 	31.681 % complete
#
#
# 	31.696 % complete
#
#
# 	31.710 % complete
#
#
# 	31.725 % complete
#
#
# 	31.739 % complete
#
#
# 	31.754 % complete
#
#
# 	31.768 % complete
#
#
# 	31.783 % complete
#
#
# 	31.797 % complete
#
#
# 	31.812 % complete
#
#
# 	31.826 % complete
#
#
# 	31.841 % complete
#
#
# 	31.855 % complete
#
#
# 	31.870 % complete
#
#
# 	31.884 % complete
#
#
# 	31.899 % complete
#
#
# 	31.913 % complete
#
#
# 	31.928 % complete
#
#
# 	31.942 % complete
#
#
# 	31.957 % complete
#
#
# 	31.971 % complete
#
#
# 	31.986 % complete
#
#
# 	32.000 % complete
#
#
# 	32.014 % complete
#
#
# 	32.029 % complete
#
#
# 	32.043 % complete
#
#
# 	32.058 % complete
#
#
# 	32.072 % complete
#
#
# 	32.087 % complete
#
#
# 	32.101 % complete
#
#
# 	32.116 % complete
#
#
# 	32.130 % complete
#
#
# 	32.145 % complete
#
#
# 	32.159 % complete
#
#
# 	32.174 % complete
#
#
# 	32.188 % complete
#
#
# 	32.203 % complete
#
#
# 	32.217 % complete
#
#
# 	32.232 % complete
#
#
# 	32.246 % complete
#
#
# 	32.261 % complete
#
#
# 	32.275 % complete
#
#
# 	32.290 % complete
#
#
# 	32.304 % complete
#
#
# 	32.319 % complete
#
#
# 	32.333 % complete
#
#
# 	32.348 % complete
#
#
# 	32.362 % complete
#
#
# 	32.377 % complete
#
#
# 	32.391 % complete
#
#
# 	32.406 % complete
#
#
# 	32.420 % complete
#
#
# 	32.435 % complete
#
#
# 	32.449 % complete
#
#
# 	32.464 % complete
#
#
# 	32.478 % complete
#
#
# 	32.493 % complete
#
#
# 	32.507 % complete
#
#
# 	32.522 % complete
#
#
# 	32.536 % complete
#
#
# 	32.551 % complete
#
#
# 	32.565 % complete
#
#
# 	32.580 % complete
#
#
# 	32.594 % complete
#
#
# 	32.609 % complete
#
#
# 	32.623 % complete
#
#
# 	32.638 % complete
#
#
# 	32.652 % complete
#
#
# 	32.667 % complete
#
#
# 	32.681 % complete
#
#
# 	32.696 % complete
#
#
# 	32.710 % complete
#
#
# 	32.725 % complete
#
#
# 	32.739 % complete
#
#
# 	32.754 % complete
#
#
# 	32.768 % complete
#
#
# 	32.783 % complete
#
#
# 	32.797 % complete
#
#
# 	32.812 % complete
#
#
# 	32.826 % complete
#
#
# 	32.841 % complete
#
#
# 	32.855 % complete
#
#
# 	32.870 % complete
#
#
# 	32.884 % complete
#
#
# 	32.899 % complete
#
#
# 	32.913 % complete
#
#
# 	32.928 % complete
#
#
# 	32.942 % complete
#
#
# 	32.957 % complete
#
#
# 	32.971 % complete
#
#
# 	32.986 % complete
#
#
# 	33.000 % complete
#
#
# 	33.014 % complete
#
#
# 	33.029 % complete
#
#
# 	33.043 % complete
#
#
# 	33.058 % complete
#
#
# 	33.072 % complete
#
#
# 	33.087 % complete
#
#
# 	33.101 % complete
#
#
# 	33.116 % complete
#
#
# 	33.130 % complete
#
#
# 	33.145 % complete
#
#
# 	33.159 % complete
#
#
# 	33.174 % complete
#
#
# 	33.188 % complete
#
#
# 	33.203 % complete
#
#
# 	33.217 % complete
#
#
# 	33.232 % complete
#
#
# 	33.246 % complete
#
#
# 	33.261 % complete
#
#
# 	33.275 % complete
#
#
# 	33.290 % complete
#
#
# 	33.304 % complete
#
#
# 	33.319 % complete
#
#
# 	33.333 % complete
#
#
# 	33.348 % complete
#
#
# 	33.362 % complete
#
#
# 	33.377 % complete
#
#
# 	33.391 % complete
#
#
# 	33.406 % complete
#
#
# 	33.420 % complete
#
#
# 	33.435 % complete
#
#
# 	33.449 % complete
#
#
# 	33.464 % complete
#
#
# 	33.478 % complete
#
#
# 	33.493 % complete
#
#
# 	33.507 % complete
#
#
# 	33.522 % complete
#
#
# 	33.536 % complete
#
#
# 	33.551 % complete
#
#
# 	33.565 % complete
#
#
# 	33.580 % complete
#
#
# 	33.594 % complete
#
#
# 	33.609 % complete
#
#
# 	33.623 % complete
#
#
# 	33.638 % complete
#
#
# 	33.652 % complete
#
#
# 	33.667 % complete
#
#
# 	33.681 % complete
#
#
# 	33.696 % complete
#
#
# 	33.710 % complete
#
#
# 	33.725 % complete
#
#
# 	33.739 % complete
#
#
# 	33.754 % complete
#
#
# 	33.768 % complete
#
#
# 	33.783 % complete
#
#
# 	33.797 % complete
#
#
# 	33.812 % complete
#
#
# 	33.826 % complete
#
#
# 	33.841 % complete
#
#
# 	33.855 % complete
#
#
# 	33.870 % complete
#
#
# 	33.884 % complete
#
#
# 	33.899 % complete
#
#
# 	33.913 % complete
#
#
# 	33.928 % complete
#
#
# 	33.942 % complete
#
#
# 	33.957 % complete
#
#
# 	33.971 % complete
#
#
# 	33.986 % complete
#
#
# 	34.000 % complete
#
#
# 	34.014 % complete
#
#
# 	34.029 % complete
#
#
# 	34.043 % complete
#
#
# 	34.058 % complete
#
#
# 	34.072 % complete
#
#
# 	34.087 % complete
#
#
# 	34.101 % complete
#
#
# 	34.116 % complete
#
#
# 	34.130 % complete
#
#
# 	34.145 % complete
#
#
# 	34.159 % complete
#
#
# 	34.174 % complete
#
#
# 	34.188 % complete
#
#
# 	34.203 % complete
#
#
# 	34.217 % complete
#
#
# 	34.232 % complete
#
#
# 	34.246 % complete
#
#
# 	34.261 % complete
#
#
# 	34.275 % complete
#
#
# 	34.290 % complete
#
#
# 	34.304 % complete
#
#
# 	34.319 % complete
#
#
# 	34.333 % complete
#
#
# 	34.348 % complete
#
#
# 	34.362 % complete
#
#
# 	34.377 % complete
#
#
# 	34.391 % complete
#
#
# 	34.406 % complete
#
#
# 	34.420 % complete
#
#
# 	34.435 % complete
#
#
# 	34.449 % complete
#
#
# 	34.464 % complete
# 	34.478 % complete
#
#
# 	34.493 % complete
#
#
# 	34.507 % complete
#
#
# 	34.522 % complete
#
#
# 	34.536 % complete
#
#
# 	34.551 % complete
#
#
# 	34.565 % complete
#
#
# 	34.580 % complete
#
#
# 	34.594 % complete
#
#
# 	34.609 % complete
#
#
# 	34.623 % complete
#
#
# 	34.638 % complete
#
#
# 	34.652 % complete
#
#
# 	34.667 % complete
#
#
# 	34.681 % complete
#
#
# 	34.696 % complete
#
#
# 	34.710 % complete
#
#
# 	34.725 % complete
#
#
# 	34.739 % complete
#
#
# 	34.754 % complete
#
#
# 	34.768 % complete
#
#
# 	34.783 % complete

# %%
# UNCOMMENT TO LOAD SAVED GLOBAL FITTED TS DATA:

# load saved data and reshape it from 2d to 3d
#ts_arr_2d = np.loadtxt(os.path.join(data_dir, 'fitted_ts_array_%s%s.txt' % (dataset, mask_filename_ext)))
ts_arr = ts_arr_2d.reshape(ts_arr_2d.shape[0],
                           ts_arr_2d.shape[1] // coeffs.shape[2],
                           coeffs.shape[2])

# get coords arrays
X, Y = np.meshgrid(coeffs.x, coeffs.y)

# %%
#########
# RUN EOF
#########
if run_eof:

    # calculate weights array requested
    if lat_weights == 'cos':
        weights = np.cos(np.deg2rad(Y))
        weights /= weights.mean()
    elif lat_weights == 'sqrt_cos':
        weights = np.sqrt(np.cos(np.deg2rad(Y)))
        weights /= weights.mean()
    else:
        weights = None


    # coerce ts array to rio xarray obj
    ts_da = xr.DataArray([coeffs[0,:,:]*np.nan]*365) 
    ts_da.attrs = coeffs.attrs
    ts_da.attrs['long_name'] = ['d%i' % i for i in range(1, 366)]
    ts_da = ts_da.rename({'dim_0': 'time',
                          'dim_1': 'y',
                          'dim_2': 'x',
                          })
    ts_da = ts_da.assign_coords({'time': range(1, 366),
                                 'y': coeffs.y.values,
                                 'x': coeffs.x.values,
                                 })
    ts_da = ts_da.rio.write_crs(4326)
    ts_da.rio.set_crs(4326)
    ts_da.loc[:,:,:] = ts_arr

    # use empirical orthogonal functions to collapse global ts into
    # main modes of variation
    solver = Eof(ts_da, weights=weights)

# %%
    # grab the first n EOFs
    # (and swap axes so that 3rd axis is of length neofs, to facilitate image
    # plotting)
    eofs = solver.eofsAsCorrelation(neofs=neofs)

    # grab the PCs
    pcs = solver.pcs(npcs=neofs, pcscaling=1)

    # grab pct variances of EOFs
    var_pcts = solver.varianceFraction(neofs)

    # reconstruct the field using just the selected top EOFs
    ts_recon = solver.reconstructedField(neofs)

    # write eofs to file, if requested
    if save_res:
        tif_filename = '%s_%s_%i_EOFs_%s%s%s.tif' % (dataset,
                                                     region_name,
                                                     neofs,
                                                     lat_weights + 'wts',
                                                     '_normts' * normalize_ts,
                                                     mask_filename_ext,
                                                      )
        eof_res_for_file = eofs.to_dataset('mode')
        eof_res_for_file = eof_res_for_file.rename_vars(
                                        {i: 'eof%i' % i for i in range(neofs)})
        eof_res_for_file.rio.to_raster(os.path.join(data_dir, tif_filename),
                           dtype=np.float32,
                           tags={'eof%i_pctvar' % i:
                                 str(var_pcts.values[i]) for i in range(neofs)},
                          )

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(111)
eofs.sel(mode=1).plot.imshow(ax=ax)

# %%
fig, ax = plt.subplots(1,1)
ax.plot(solver.varianceFraction(10)*100)
ax.set_title('pct variance explained by first 10 EOFs')
ax.set_xlabel('EOF number')
ax.set_ylabel('pct variance explained')
print([*solver.varianceFraction(10).values*100])
# Out:
# [69.98064, 17.682697, 7.873182, 4.46348, 4.4450374e-11, 3.2240052e-15, 3.2232268e-15, 3.2197435e-15, 3.2184207e-15, 3.2175874e-15]

# %%
if run_eof:
    #########################################################################
    # MAP AND PLOT CHARACTERISTIC SEASONAL PATTERNS AT ENDS OF EACH EOF RANGE
    #########################################################################

    fig = plt.figure(figsize=(12,9))
    gs = fig.add_gridspec(nrows=neofs, ncols=5, width_ratios=[1,0.3,1,0.3,1])
    for neof in range(neofs):
        ax_map = fig.add_subplot(gs[neof, 0])
        eofs.sel(mode=neof).plot.imshow(ax=ax_map)
        ax_map.set_aspect('equal')
        ax_map.set_xticks(())
        ax_map.set_yticks(())
        ax_map.set_xticklabels(())
        ax_map.set_yticklabels(())
        ax_map.set_ylabel('mode %i' % neof, fontdict={'fontsize': 20})
        ax_map.set_title('%0.1f%% of variation' % (var_pcts[neof]*100))
        ax_pc_plot = fig.add_subplot(gs[neof,2])
        ax_pc_plot.set_xlabel('time of year')
        ax_pc_plot.set_xticks(np.linspace(0, 365, 5), ['Jan', 'Apr', 'Jul',
                                                       'Oct', 'Jan'])
        pcs.sel(mode=neof).plot(ax=ax_pc_plot)
        ax_pc_plot.set_title('annual variation')
        ax_pc_plot.set_ylabel('scaled PC value')
        ax_examp_ts = fig.add_subplot(gs[neof,4])
        top_ts = ts_recon.values[:,
            eofs.sel(mode=neof)>=np.nanpercentile(eofs.sel(mode=neof), ts_top_pctile)].T
        idxs_to_plot = np.random.choice(range(top_ts.shape[0]), size=n_ts_to_plot, replace=False)
        ts_to_plot = top_ts[idxs_to_plot,:]
        for ts in ts_to_plot:
            ax_examp_ts.plot(range(365), ts, alpha=0.05, color='#850c10')
        bot_ts = ts_recon.values[:,
            eofs.sel(mode=neof)<=np.nanpercentile(eofs.sel(mode=neof), ts_bot_pctile)].T
        idxs_to_plot = np.random.choice(range(bot_ts.shape[0]), size=n_ts_to_plot, replace=False)
        ts_to_plot = bot_ts[idxs_to_plot,:]
        for ts in ts_to_plot:
            ax_examp_ts.plot(range(365), ts, alpha=0.05, color='#0b489e')
        ax_examp_ts.set_xlabel('time of year')
        ax_examp_ts.set_ylabel('scaled magnitude')
        ax_examp_ts.set_title(('seasonality at 95th pctile (red)\n'
                            'and 5th pctile (blue) of mode %i pixels') % neof)
        ax_examp_ts.set_xticks(np.linspace(0, 365, 5), ['Jan', 'Apr', 'Jul',
                                                        'Oct', 'Jan'])
    fig.subplots_adjust(left=subplots_adj_left,
                         bottom=subplots_adj_bottom,
                         right=subplots_adj_right,
                         top=subplots_adj_top,
                         wspace=subplots_adj_wspace,
                         hspace=subplots_adj_hspace)
    fig.show()
    if save_res:
        fig_filename = '%s_%s_EOF_results_scat_%s%s%s.png' % (dataset,
                                                                region_name,
                                                                lat_weights + 'wts',
                                                                '_normts' * normalize_ts,
                                                                mask_filename_ext,
                                                               )
        fig.savefig(os.path.join(data_dir, fig_filename), dpi=500)

# %%
if run_eof:
    ##################################### 
    # USE HVPLOT FOR INTERACTIVE PLOTTING
    ##################################### 

    eofs4 = solver.eofsAsCorrelation(neofs=4)
    if interactive:

        # plot top 3 EOFs as RGB image
        rgb_plot = eofs4[1:].hvplot.rgb(x='x', y='y', bands='mode',
                                   geo=True,
                                   #coastlines=True,
                                   alpha=0.4,
                                   #responsive=True,
                                   width=800,
                                   height=600,
                                   title='top 3 EOFs in R, G, B channels',
                                   tiles='EsriReference',
                                   data_aspect=1)
        pn.serve(rgb_plot)
    else:
        fig2 = plt.figure(figsize=(16,8))
        ax_rgb = fig2.add_subplot(111)
        eofs4[1:].plot.imshow(ax=ax_rgb)
        fig2.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#######################
# EMBED IN 3D USING MDS
#######################
if run_mds:

    # take subsample of full grid

    # use metric multidimensional scaling to embed sample points' 365-length
    # time series in 3-dimensional space (which I'll then map to RGB for mapping),
    # using pairwise Euclidean distance between the 365-d points as dissim metric
    mds_ts_arr = ts_arr.reshape(ts_arr.shape[0],-1).T
    mds_ts_arr = mds_ts_arr[~np.isnan(mds_ts_arr).any(axis=1)]
    mds = MDS(n_components=3, metric=True)
    mds_axes = mds.fit_transform(mds_ts_arr)
    # normalize the mds_axes columns, to then map onto RGB colors
    mds_axes_norm = ((mds_axes - np.min(mds_axes, axis=0)) /
                   (np.max(mds_axes, axis=0) - np.min(mds_axes, axis=0)))

# %%
if run_mds:
    #####################################################
    # PLOT IN 3D, AND MAP, AND PLOT CHARACTERISTIC CURVES
    #####################################################

    #grid MDS values
    mds_res = coeffs[:3,:,:]*np.nan
    mds_val_ct = 0
    for x, y in zip(X.flatten(), Y.flatten()):
        if not np.isnan(coeffs[0,:,:].sel(x=x, y=y)):
            mds_res.loc[{'x':x, 'y':y}] = mds_axes_norm[mds_val_ct,:]
            mds_val_ct += 1

    # write gridded results to raster
    try:
        scale_factor = mds_res.attrs['scale_factor']
    except Exception:
        scale_factor = 1.
    try:
        add_offset = mds_res.attrs['add_offset']
    except Exception:
        add_offset = 0.
    try:
        _FillValue = mds_res.attrs['_FillValue']
    except Exception:
        _FillValue = -9999
    mds_res.attrs.clear()
    mds_res.attrs['scale_factor'] = scale_factor
    mds_res.attrs['add_offset'] = add_offset
    mds_res.attrs['_FillValue'] = _FillValue
    mds_res.attrs['long_name'] = ['R', 'G', 'B']

    outfilename = os.path.join(data_dir,  '%s_MDS_res.tif' % region_name)
    mds_res.rio.to_raster(outfilename)


    # map results
    fig4 = plt.figure(figsize=(16,12))
    gs = fig4.add_gridspec(nrows=6, ncols=4,
                           width_ratios=[1,1,0.5,0.5])
    ax_scat = fig4.add_subplot(gs[:3, 2:4], projection='3d')
    ax_scat.scatter(mds_axes[:,0], mds_axes[:,1], mds_axes[:,2],
                    c=mds_axes_norm, alpha=0.05)
    ax_scat.set_xlabel('MDS AX 1')
    ax_scat.xaxis.label.set_color('red')
    ax_scat.set_ylabel('MDS AX 2')
    ax_scat.yaxis.label.set_color('green')
    ax_scat.set_zlabel('MDS AX 3')
    ax_scat.zaxis.label.set_color('blue')
    ax_scat.set_xticks(())
    ax_scat.set_xticklabels(())
    ax_scat.set_yticks(())
    ax_scat.set_yticklabels(())
    ax_scat.set_zticks(())
    ax_scat.set_zticklabels(())

    ax_map = fig4.add_subplot(gs[:,0:2])
    countries = gpd.read_file(os.path.join(data_dir, 'NewWorldFile_2020.shp'))
    countries = countries.to_crs(4326)
    countries.plot(facecolor='none',
                   edgecolor='black',
                   linewidth=0.5,
                   ax=ax_map)
    mds_res.plot.imshow(ax=ax_map)
    ax_map.set_xlim((np.min(coeffs.x), np.max(coeffs.x)))
    ax_map.set_ylim((np.min(coeffs.y), np.max(coeffs.y)))
    ax_map.set_xlabel('')
    ax_map.set_ylabel('')
    ax_map.set_xticks(())
    ax_map.set_xticklabels(())
    ax_map.set_yticks(())
    ax_map.set_yticklabels(())
    ax_map.set_title('')
    ax_ax1_lo = fig4.add_subplot(gs[3,2])
    ax_ax1_hi = fig4.add_subplot(gs[3,3])
    ax_ax2_lo = fig4.add_subplot(gs[4,2])
    ax_ax2_hi = fig4.add_subplot(gs[4,3])
    ax_ax3_lo = fig4.add_subplot(gs[5,2])
    ax_ax3_hi = fig4.add_subplot(gs[5,3])
    for i in zip(*np.where(mds_axes[:,0]<=np.percentile(mds_axes[:,0], 5))):
        ax_ax1_lo.plot(range(365), mds_ts_arr[i], alpha=0.1, color=mds_axes_norm[i])
    for i in zip(*np.where(mds_axes[:,0]>=np.percentile(mds_axes[:,0], 95))):
        ax_ax1_hi.plot(range(365), mds_ts_arr[i], alpha=0.1, color=mds_axes_norm[i])
    for i in zip(*np.where(mds_axes[:,1]<=np.percentile(mds_axes[:,1], 5))):
        ax_ax2_lo.plot(range(365), mds_ts_arr[i], alpha=0.1, color=mds_axes_norm[i])
    for i in zip(*np.where(mds_axes[:,1]>=np.percentile(mds_axes[:,1], 95))):
        ax_ax2_hi.plot(range(365), mds_ts_arr[i], alpha=0.1, color=mds_axes_norm[i])
    for i in zip(*np.where(mds_axes[:,2]<=np.percentile(mds_axes[:,2], 5))):
        ax_ax3_lo.plot(range(365), mds_ts_arr[i], alpha=0.1, color=mds_axes_norm[i])
    for i in zip(*np.where(mds_axes[:,2]>=np.percentile(mds_axes[:,2], 95))):
        ax_ax3_hi.plot(range(365), mds_ts_arr[i], alpha=0.1, color=mds_axes_norm[i])
    ax_ax1_lo.set_ylabel('MDS AX1')
    ax_ax1_lo.yaxis.label.set_color('red')
    ax_ax2_lo.set_ylabel('MDS AX2')
    ax_ax2_lo.yaxis.label.set_color('green')
    ax_ax3_lo.set_ylabel('MDS AX3')
    ax_ax3_lo.yaxis.label.set_color('blue')
    ax_ax3_lo.set_xlabel('time of year')
    ax_ax3_hi.set_xlabel('time of year')
    ax_ax3_lo.set_xticks(np.linspace(0, 365, 5), ['Jan', 'Apr', 'Jul', 'Oct', 'Jan'])
    ax_ax3_hi.set_xticks(np.linspace(0, 365, 5), ['Jan', 'Apr', 'Jul', 'Oct', 'Jan'])
    for ax in [ax_ax1_lo, ax_ax1_hi, ax_ax2_lo, ax_ax2_hi, ax_ax3_lo, ax_ax3_hi]:
        ax.set_yticks(())
        ax.set_yticklabels(())
    for ax in [ax_ax1_lo, ax_ax1_hi, ax_ax2_lo, ax_ax2_hi]:
        ax.set_xticks(())
        ax.set_xticklabels(())
    fig4.subplots_adjust(left=subplots_adj_left,
                         bottom=subplots_adj_bottom,
                         right=subplots_adj_right,
                         top=subplots_adj_top,
                         wspace=subplots_adj_wspace,
                         hspace=subplots_adj_hspace)
    if save_res:
        fig4_filename = '%s_MDS_results_scat.png' % region_name
        fig4.savefig(os.path.join(data_dir, fig4_filename), dpi=100)
    fig4.show()
